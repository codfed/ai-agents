# %% [markdown]
# # Trending Wikipedia
#
# 1. Get trending Wikipedia articles from yesterday
# 2. Pass plain text from article to OpenAI for suggestsions as to why each article is trending
# 3. Build HTML page to display each article and why it is trending
#
# #### But this time with phoenix to trace it and iterate!
#
# # Take away
# #### What I've played around using Phoenix
#
# The traces visible in Phoenix make it so much easier to look at the entire prompt and result to get a better insight into the results than you can get through print statements in the notebook. I see it as a magnifying glass and complete historic record.
#
# - For Jimmy Carter's article, it needed 500 characters to get the general detail of his recent death in December 2024 and 2000 characters to get the context the full date of death
# - droping max_tokens from 2048 to 512 didn't have a discernable difference
# - Changing the prompt from "In 1-2 sentences, explain why the..." to "In 1 concise and confident sentence, explain why..." gave results I prefer

# %%
# !pip install requests python-dotenv openai arize-phoenix openinference-instrumentation-openai

# %%
from dotenv import load_dotenv
import os

load_dotenv()

OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]

# %% [markdown]
# # The Phoenix part
#
# 1. Launch Phoenix
# 2. Register Phoenix as the trace provider
# 3. Initialize the OpenAI Instrumentor with the Phoenix trace provider
#
# After all these are finished, all of our calls to ChatGPT will be recorded

# %% [markdown]
# #### Launch Phoenix
# This will lauch phoenix locally. We will connect to this later on in the notebook.
#
# Note: This cell will give benign errors if you run it twice.

# %%
import phoenix as px
px.launch_app()

# %% [markdown]
# #### Connect OpenAI Instrumentor to Phoenix

# %%
from phoenix.otel import register
from openinference.instrumentation.openai import OpenAIInstrumentor

tracer_provider = register(
  project_name="trending-wikipedia-phoenix-tracing", # Default is 'default'
)

OpenAIInstrumentor().instrument(tracer_provider=tracer_provider)

# %% [markdown]
# ### Now each time we use OpenAI, it will be logged in our Phoenix application

# %% [markdown]
# API call for the featured feed shows different for today than it does for any previous days.
#
# This is written for previous days only

# %%
import requests
import datetime

today = datetime.datetime.now()
yesterday = today - datetime.timedelta(days=1)

date_to_query = yesterday
url = 'https://api.wikimedia.org/feed/v1/wikipedia/en/featured/' + date_to_query.strftime('%Y/%m/%d')


response = requests.get(url)
featured_feed = response.json()
print(f"API call: {url}")
print(f"Retrieved Wikipedia top article statistics for {date_to_query}")

# %% [markdown]
# ### Save API response to file

# %%
import os
import json

# Ensure the 'featured-feed' folder exists
file_directory = "data"
os.makedirs(file_directory, exist_ok=True)

# Define the filename based on the date
base_file_name = date_to_query.strftime('%Y-%m-%d')
file_path = f'{file_directory}/{base_file_name}.json'

# Save to JSON file (overwrite if it already exists)
with open(file_path, 'w', encoding='utf-8') as file:
    json.dump(featured_feed, file, indent=4, ensure_ascii=False)

print(f'Saved Wikipedia response to {file_path}')

# %% [markdown]
# ### Make `article_list` with only relevant information

# %%
article_list = []

for item in featured_feed['mostread']['articles'][:20]:
    title = item['title']
    views = item['views']
    link = item['content_urls']['desktop']['page']
    extract = item['extract']
    thumbnail = item.get('thumbnail', {}).get('source', None)

    print(f"Getting full text of {title} article")


    # Download raw text of article
    url = f"https://en.wikipedia.org/w/index.php?title={title}&action=raw"
    print(url)

    article_text = requests.get(url).text
    article_text_truncated = article_text[:5000]

    
    
    article={
        'title': title,
        'views': views,
        'link': link,
        'thumbnail': thumbnail,
        'extract': extract,
        'text': article_text_truncated,
        'trendingreason': ''
    }

    article_list.append(article)

print(article_list)

# %% [markdown]
# ### Run through article list, prompt ChatGPT to decifer reasons for trending based on the infomration provided.

# %%
from openai import OpenAI
client = OpenAI(api_key=OPENAI_API_KEY)

for article in article_list:
    print(f"Analyzing {title}")

    title = article['title']
    text = article['text']

    prompt = f"Act as a professional news summarizer. Based on your knowledge of {title} and the following extract. In 1 concise and confident sentence, explain why the {title} article might be trending on Wikipedia on #{date_to_query}:\n\n{text}"

    response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "user",
        "content": prompt
        }
    ],
    temperature=1,
    max_tokens=512,
    top_p=1
    )
    print(f"trendingreason: {response.choices[0].message.content}")
    
    article['trendingreason'] =  response.choices[0].message.content

# %% [markdown]
# Kept running into rate limit errors... But the results I was getting are very positive and close to what I was looking for.
#
# On the downside.. running this for two days hit the Tokens Per Minute limits and cost almost $7....
#
# This is enough for this

# %% [markdown]
# ### Save vital information to new file

# %%
file_path = f'{file_directory}/{base_file_name}-trending-reasons.json'

# Save to JSON file (overwrite if it already exists)
with open(file_path, 'w', encoding='utf-8') as file:
    json.dump(article_list, file, indent=4, ensure_ascii=False)

print(f'articles_with_reasons saved to {file_path}')

# %% [markdown]
# #### Build HTML Page to display the top 10 list complete with thumbnails and the reason generated by ChatGPT

# %%
# Start building the HTML
html_title = f"<h1>Wikipedia's most viewed articles on {date_to_query.strftime("%B %d, %Y")}</h1>"
html_list = "<ol>\n"

# Iterate through the data
for item in article_list:
    title = item['title']
    link = item['link']
    thumbnail = item['thumbnail']
    trendingreason = item['trendingreason']
    views = item['views']
    extract = item['extract']

    # Handle null thumbnail
    if thumbnail:
        thumbnail_html = f'<img src="{thumbnail}" alt="Thumbnail for {title}"/><br>'
    else:
        thumbnail_html = '<p><em>No thumbnail available</em></p>'
    
    # Create a list item for each entry
    html_list += f"""
    <li>
        <h2>
          <a href="{link}" target="_blank">{title}</a><br>
        </h2>
        {thumbnail_html}
        <strong>Views:</strong> {views}<br><br>
        <strong>Reason for Trending:</strong> {trendingreason}
    </li>\n
    """

# Close the HTML list
html_list += "</ol>"

html_page = html_title + html_list
# Save to html file (overwrite if it already exists)
file_path = f'{file_directory}/{base_file_name}.html'

with open(file_path, 'w', encoding='utf-8') as file:
    file.write(html_page)

# Display the HTML in the notebook
from IPython.display import display, HTML
display(HTML(html_page))
# Out:
# <h1>Wikipedia's most viewed articles on January 06, 2025</h1><ol>
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Jeff_Baena" target="_blank">Jeff_Baena</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/d/dc/Jeff_Baena.jpg/320px-Jeff_Baena.jpg" alt="Thumbnail for Jeff_Baena"/><br>
#         <strong>Views:</strong> 502003<br><br>
#         <strong>Reason for Trending:</strong> The Jeff Baena article is trending on Wikipedia due to his recent death on January 3, 2025, at the age of 47, which has prompted an outpouring of remembrance and recognition of his contributions to film as a director and screenwriter.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Aubrey_Plaza" target="_blank">Aubrey_Plaza</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/29/Aubrey_Plaza_at_the_2024_Cannes_Film_Festival_%28cropped%29.jpg/320px-Aubrey_Plaza_at_the_2024_Cannes_Film_Festival_%28cropped%29.jpg" alt="Thumbnail for Aubrey_Plaza"/><br>
#         <strong>Views:</strong> 448782<br><br>
#         <strong>Reason for Trending:</strong> The Aubrey Plaza article is likely trending on Wikipedia due to her recent acclaim and visibility following her role in the HBO series "The White Lotus," which garnered nominations for prestigious awards, along with her starring role in the 2024 Marvel Cinematic Universe miniseries "Agatha All Along."
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/The_Vivienne" target="_blank">The_Vivienne</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/31/RuPaul_with_All_Stars_7_Contestants_at_LA_DragCon_2022_by_dvsross_%28crop_-_The_Vivienne%29.jpg/320px-RuPaul_with_All_Stars_7_Contestants_at_LA_DragCon_2022_by_dvsross_%28crop_-_The_Vivienne%29.jpg" alt="Thumbnail for The_Vivienne"/><br>
#         <strong>Views:</strong> 388341<br><br>
#         <strong>Reason for Trending:</strong> The article on The Vivienne is trending on Wikipedia following the news of their untimely death at the age of 32, which has sparked significant public interest due to their notable achievements as a pioneering drag performer and television personality in the UK.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Squid_Game_season_2" target="_blank">Squid_Game_season_2</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/en/3/38/Squid_Game_season_2_poster.png" alt="Thumbnail for Squid_Game_season_2"/><br>
#         <strong>Views:</strong> 287270<br><br>
#         <strong>Reason for Trending:</strong> The article about "Squid Game Season 2" is trending on Wikipedia due to its recent release on December 26, 2024, which has generated significant viewership and critical acclaim, surpassing the previous Netflix premiere record.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Brothers_Home" target="_blank">Brothers_Home</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/en/thumb/8/8f/BrothersHomeBusan.jpeg/320px-BrothersHomeBusan.jpeg" alt="Thumbnail for Brothers_Home"/><br>
#         <strong>Views:</strong> 242999<br><br>
#         <strong>Reason for Trending:</strong> The Brothers' Home article is likely trending on Wikipedia due to renewed public interest and discussion surrounding its historical significance and the human rights abuses that occurred there, particularly in light of continuing global conversations about past injustices and accountability in South Korea.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Nosferatu_(2024_film)" target="_blank">Nosferatu_(2024_film)</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/en/4/48/Nosferatu_IMAX_poster_2024.jpg" alt="Thumbnail for Nosferatu_(2024_film)"/><br>
#         <strong>Views:</strong> 228206<br><br>
#         <strong>Reason for Trending:</strong> The Nosferatu (2024 film) article is likely trending on Wikipedia due to its recent theatrical release on December 25, 2024, subsequent box office success surpassing $100 million, and positive critical reception following its world premiere in Berlin, which has generated significant public interest.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Squid_Game" target="_blank">Squid_Game</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/e4/Squid_Game_2021_vector_logo.svg/320px-Squid_Game_2021_vector_logo.svg.png" alt="Thumbnail for Squid_Game"/><br>
#         <strong>Views:</strong> 196361<br><br>
#         <strong>Reason for Trending:</strong> The article on "Squid Game" is likely trending on Wikipedia as of January 6, 2025, due to the recent release of its highly anticipated second season on Netflix, which has generated renewed interest and discussions surrounding the series.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Human_metapneumovirus" target="_blank">Human_metapneumovirus</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/e1/Pathogens-04-00682-g001.png/320px-Pathogens-04-00682-g001.png" alt="Thumbnail for Human_metapneumovirus"/><br>
#         <strong>Views:</strong> 193898<br><br>
#         <strong>Reason for Trending:</strong> The Human Metapneumovirus article might be trending on Wikipedia due to a recent outbreak in Northeast Asia and the detection of its first cases in India, highlighting its impact on public health.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Jimmy_Carter" target="_blank">Jimmy_Carter</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/ea/JimmyCarterPortrait_%28cropped%29.jpg/320px-JimmyCarterPortrait_%28cropped%29.jpg" alt="Thumbnail for Jimmy_Carter"/><br>
#         <strong>Views:</strong> 182161<br><br>
#         <strong>Reason for Trending:</strong> The Jimmy Carter article might be trending on Wikipedia due to increased interest following his recent passing on December 29, 2024, making him a significant figure in discussions about American history and presidential legacies.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Pushpa_2%3A_The_Rule" target="_blank">Pushpa_2:_The_Rule</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/en/1/11/Pushpa_2-_The_Rule.jpg" alt="Thumbnail for Pushpa_2:_The_Rule"/><br>
#         <strong>Views:</strong> 146375<br><br>
#         <strong>Reason for Trending:</strong> The article on "Pushpa 2: The Rule" is likely trending on Wikipedia due to its recent theatrical release on December 5, 2024, and ongoing discussions about its box office performance, which ultimately impacts its potential to become India's highest-grossing film.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Pan_Am_Flight_103" target="_blank">Pan_Am_Flight_103</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/a/a9/Pan_Am_Flight_103._Crashed_Lockerbie%2C_Scotland%2C_21_December_1988.jpg/320px-Pan_Am_Flight_103._Crashed_Lockerbie%2C_Scotland%2C_21_December_1988.jpg" alt="Thumbnail for Pan_Am_Flight_103"/><br>
#         <strong>Views:</strong> 144483<br><br>
#         <strong>Reason for Trending:</strong> The article on Pan Am Flight 103 might be trending on Wikipedia due to significant renewed interest in the case following recent discussions or developments related to the Lockerbie bombing, particularly as it marks the anniversary of the tragic event in 1988.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Mufasa%3A_The_Lion_King" target="_blank">Mufasa:_The_Lion_King</a><br>
#         </h2>
#         <img src="https://upload.wikimedi
