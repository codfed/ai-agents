# %% [markdown]
# # Trending Wikipedia articles using Langchain Memory to add context
#
# When I have run the trending analysis in my previous notebooks, I was seeing articles that related to each other, but one didn't have any new information present in the portion of the artcile I was passing.
#
# Like when Greg Gumbell died his article trended and it was updated with his death date so its trending reason was correctly identified. The article for his brother, Bryant Gumbell, also trended. But the agent was not able to figure this out.
#
# I am testing out Langchain's memory feature to try to solve this problem

# %%
#!pip install langchain langchain-openai langchain-community openai arize-phoenix openinference-instrumentation-openai

# %%
from dotenv import load_dotenv
import os

load_dotenv()

OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]

# %%
import json
from langchain_openai import ChatOpenAI
from langchain.chains import ConversationChain
from langchain.memory import ConversationBufferMemory
from langchain.prompts import ChatPromptTemplate, MessagesPlaceholder

# %% [markdown]
# ### Create function to save/load conversation memory

# %% [markdown]
# ### Get trending wikipedia articles

# %%
import requests
import datetime

today = datetime.datetime.now()
yesterday = today - datetime.timedelta(days=1)

date_to_query = yesterday
url = 'https://api.wikimedia.org/feed/v1/wikipedia/en/featured/' + date_to_query.strftime('%Y/%m/%d')


response = requests.get(url)
featured_feed = response.json()
print(f"API call: {url}")
print(f"Retrieved Wikipedia top article statistics for {date_to_query}")
# Out:
# API call: https://api.wikimedia.org/feed/v1/wikipedia/en/featured/2025/01/05
# Retrieved Wikipedia top article statistics for 2025-01-05 22:12:26.184105

# %% [markdown]
# ### Save to file

# %%
import os
import json

# Ensure the 'featured-feed' folder exists
file_directory = "data"
os.makedirs(file_directory, exist_ok=True)

# Define the filename based on the date
base_file_name = date_to_query.strftime('%Y-%m-%d')
file_path = f'{file_directory}/{base_file_name}.json'

# Save to JSON file (overwrite if it already exists)
with open(file_path, 'w', encoding='utf-8') as file:
    json.dump(featured_feed, file, indent=4, ensure_ascii=False)

print(f'Saved Wikipedia response to {file_path}')
# Out:
# Saved Wikipedia response to data/2025-01-05.json

# %% [markdown]
# ### Build data structure with all relevant information and placeholders for LLM responses

# %%
article_list = []


for item in featured_feed['mostread']['articles'][:10]:
    title = item['title']
    views = item['views']
    link = item['content_urls']['desktop']['page']
    extract = item['extract']
    thumbnail = item.get('thumbnail', {}).get('source', None)

    print(f"Getting full text of {title} article")


    # Download raw text of article
    url = f"https://en.wikipedia.org/w/index.php?title={title}&action=raw"
    print(url)

    article_text = requests.get(url).text
    article_text_truncated = article_text[:5000]

    
    
    article={
        'title': title,
        'views': views,
        'link': link,
        'thumbnail': thumbnail,
        'extract': extract,
        'text': article_text_truncated,
        'trendingreason': '',
        'memorycontext': ''
    }



    article_list.append(article)

print(article_list)
# Out:
# Getting full text of Jeff_Baena article
# https://en.wikipedia.org/w/index.php?title=Jeff_Baena&action=raw
# Getting full text of Aubrey_Plaza article
# https://en.wikipedia.org/w/index.php?title=Aubrey_Plaza&action=raw
# Getting full text of Squid_Game_season_2 article
# https://en.wikipedia.org/w/index.php?title=Squid_Game_season_2&action=raw
# Getting full text of Human_metapneumovirus article
# https://en.wikipedia.org/w/index.php?title=Human_metapneumovirus&action=raw
# Getting full text of Nosferatu_(2024_film) article
# https://en.wikipedia.org/w/index.php?title=Nosferatu_(2024_film)&action=raw
# Getting full text of Jimmy_Carter article
# https://en.wikipedia.org/w/index.php?title=Jimmy_Carter&action=raw
# Getting full text of Brothers_Home article
# https://en.wikipedia.org/w/index.php?title=Brothers_Home&action=raw
# Getting full text of Squid_Game article
# https://en.wikipedia.org/w/index.php?title=Squid_Game&action=raw
# Getting full text of Luke_Littler article
# https://en.wikipedia.org/w/index.php?title=Luke_Littler&action=raw
# Getting full text of Pan_Am_Flight_103 article
# https://en.wikipedia.org/w/index.php?title=Pan_Am_Flight_103&action=raw
# [{'title': 'Jeff_Baena', 'views': 716965, 'link': 'https://en.wikipedia.org/wiki/Jeff_Baena', 'thumbnail': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/dc/Jeff_Baena.jpg/320px-Jeff_Baena.jpg', 'extract': 'Jeffrey Baena was an American screenwriter and film director. He wrote and directed Life After Beth (2014), Joshy (2016), The Little Hours (2017), Horse Girl (2020) and Spin Me Round (2022) and co-wrote I Heart Huckabees (2004). He was known for his frequent collaborations with actresses Alison Brie, Molly Shannon, and Aubrey Plaza.', 'text': '{{Short description|American screenwriter and film director (1977–2025)|bot=PearBOT 5}}\n{{Use mdy dates|date=January 2025}}\n{{Use American English|date=January 2025}}\n{{Infobox person\n| image              = Jeff Baena.jpg\n| caption            = Baena at the 2017 [[Seattle International Film Festival]]\n| alt                = Baena posing\n| birth_name         = Jeffrey Baena\n| birth_date         = {{birth date|1977|6|29}}\n| birth_place        = [[Miami]], Florida, U.S.\n| death_date         = {{death date and age|2025|01|03|1977|06|29}}\n| death_place        = Los Angeles, California, U.S.\n| education          = [[New York University]]\n| occupation         = {{Flat list|\n* Director\n* screenwriter\n}}\n| years_active       = 2004–2025\n| spouse             = {{marriage|[[Aubrey Plaza]]|2021}}<ref name="bbc" />\n}}\n\n\'\'\'Jeffrey Baena\'\'\' (June 29, 1977 – January 3, 2025) was an American screenwriter and film director. He wrote and directed \'\'[[Life After Beth]]\'\' (2014), \'\'[[Joshy]]\'\' (2016), \'\'[[The Little Hours]]\'\' (2017), \'\'[[Horse Girl]]\'\' (2020) and \'\'[[Spin Me Round]]\'\' (2022) and co-wrote \'\'[[I Heart Huckabees]]\'\' (2004). He was known for his frequent collaborations with actresses [[Alison Brie]] (with whom he co-wrote \'\'Horse Girl\'\' and \'\'Spin Me Round\'\'), [[Molly Shannon]], and [[Aubrey Plaza]].\n\n== Early life and education ==\nBaena was born on June 29, 1977,<ref name="Igoe">{{Cite web |last=Igoe |first=Katherine J. |date=January 17, 2023 |title=Aubrey Plaza\'s Low-Key Husband Jeff Baena Is So Supportive and Cute |url=https://www.aol.com/aubrey-plazas-low-key-husband-200900350.html |access-date=January 4, 2025 |website=[[Cosmopolitan (magazine)|Cosmopolitan]] |language=en-US |via=[[AOL]]}}</ref> and grew up in a [[Jewish secularism|secular Jewish]] family in [[Miami]].<ref>{{cite news |last=Lindner |first=Emmett |date=January 4, 2025 |title=Jeff Baena, Film Director and Screenwriter, Dies at 47 |url=https://www.nytimes.com/2025/01/04/arts/jeff-baena-dead.html |url-access=limited |accessdate=January 4, 2025 |newspaper=[[The New York Times]]}}</ref><ref>{{cite magazine |last1=Russell |first1=Anna |date=June 26, 2017 |title=Jeff Baena and Aubrey Plaza\'s Medieval Adventure |url=https://www.newyorker.com/magazine/2017/07/03/jeff-baena-and-aubrey-plazas-medieval-adventure#:~:text=Baena%20grew%20up%20in%20a%20secular%20Jewish%20household%20in%20Miami. |magazine=The New Yorker}}</ref> He graduated from the [[New York University Tisch School of the Arts]] with a degree in film and moved to [[Los Angeles]] to pursue directing.<ref name="bbc">{{cite web |title=Filmmaker Jeff Baena, husband of Aubrey Plaza, dead at 47 |url=https://www.bbc.com/news/articles/cvgny622w0zo |website=BBC |access-date=January 4, 2025 |date=January 4, 2025}}</ref> \n\n== Career ==\nBaena became a production assistant for filmmaker [[Robert Zemeckis]] on \'\'[[What Lies Beneath]]\'\' and \'\'[[Cast Away]]\'\' (both 2000).<ref name="Zax">{{Cite news |last=Zax |first=David |date=February 3, 2016 |title=How A Freak Eye Injury Became A Career Turning Point For The Director Of \'\'Joshy\'\' |url=http://www.fastcompany.com/3056144/most-creative-people/how-a-freak-eye-injury-became-a-career-turning-point-for-the-director-o |archive-url=http://web.archive.org/web/20161003150842/https://www.fastcompany.com/3056144/most-creative-people/how-a-freak-eye-injury-becam ...

# %%
# def save_memory(memory, filename="trending-history.json"):
#     with open(filename, "w") as f:
#         json.dump(memory.chat_memory.messages, f, default=lambda x: x.__dict__)

# def load_memory(filename="trending-history.json"):
#     try:
#         with open(filename, "r") as f:
#             messages = json.load(f)
#         memory = ConversationBufferMemory(return_messages=True)
#         memory.chat_memory.messages = messages
#         return memory
#     except FileNotFoundError:
#         return ConversationBufferMemory(return_messages=True)

# %% [markdown]
# ### Creating conversation chain

# %%
trending_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful Wikipedia analyst and historian. You speak consiseley and given the choice to say too much or too little, you say too little"),
    MessagesPlaceholder(variable_name="history"),
    ("human", "{input}")
])

# memory = ConversationBufferMemory()
memory = ConversationBufferMemory(return_messages=True)

# Ensure the memory's history is a list
# assert isinstance(memory.chat_memory.messages, list), "Memory history is not initialized as a list."

llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.7,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # api_key="...",  # if you prefer to pass api key in directly instaed of using env vars
    # base_url="...",
    # organization="...",
    # other params...
)

trending_conversation = ConversationChain(
    llm=llm,
    memory=memory,
    prompt=trending_prompt,
    verbose=True
)

# %% [markdown]
# #### Loop through all articles in data structure
# - Use LangChain/ChatGPT to give suggestions why each one is trending
# - Save reason to structure

# %%
for article in article_list:
    print(f"Analyzing {title}")

    title = article['title']
    text = article['text']

    prediction_prompt = f"Act as a professional news summarizer. Based on your knowledge of {title} and the following extract. In 1 concise and confident sentence, explain why the {title} article might be trending on Wikipedia on #{date_to_query}:\n\n{text}"

    response = trending_conversation.predict(input=prediction_prompt)
    print("trendingreason:", response)
    
    article['trendingreason'] =  response

# save_memory(trending_conversation.memory)
# Out:
# Analyzing Jeff_Baena
#
#
# > Entering new ConversationChain chain...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 9
#       5 text = article['text']
#       7 prediction_prompt = f"Act as a professional news summarizer. Based on your knowledge of {title} and the following extract. In 1 concise and confident sentence, explain why the {title} article might be trending on Wikipedia on #{date_to_query}:\n\n{text}"
# ----> 9 response = trending_conversation.predict(input=prediction_prompt)
#      10 print("trendingreason:", response)
#      12 article['trendingreason'] =  response
#
# File ~/devel/ai-agents/.venv/lib/python3.12/site-packages/langchain/chains/llm.py:318, in LLMChain.predict(self, callbacks, **kwargs)
#     303 def predict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#     304     """Format prompt with kwargs and pass to LLM.
#     305
#     306     Args:
#    (...)
#     316             completion = llm.predict(adjective="funny")
#     317     """
# --> 318     return self(kwargs, callbacks=callbacks)[self.output_key]
#
# File ~/devel/ai-agents/.venv/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:182, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     180     warned = True
#     181     emit_warning()
# --> 182 return wrapped(*args, **kwargs)
#
# File ~/devel/ai-agents/.venv/lib/python3.12/site-packages/langchain/chains/base.py:389, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     357 """Execute the chain.
#     358
#     359 Args:
#    (...)
#     380         `Chain.output_keys`.
#     381 """
#     382 config = {
#     383     "callbacks": callbacks,
#     384     "tags": tags,
#     385     "metadata": metadata,
#     386     "run_name": run_name,
#     387 }
# --> 389 return self.invoke(
#     390     inputs,
#     391     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     392     return_only_outputs=return_only_outputs,
#     393     include_run_info=include_run_info,
#     394 )
#
# File ~/devel/ai-agents/.venv/lib/python3.12/site-packages/langchain/chains/base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# File ~/devel/ai-agents/.venv/lib/python3.12/site-packages/langchain/chains/base.py:160, in Chain.invoke(self, input, config, **kwargs)
#     157 try:
#     158     self._validate_inputs(inputs)
#     159     outputs = (
# --> 160         self._call(inputs, run_manager=run_manager)
#     161         if new_arg_supported
#     162         else self._call(inputs)
#     163     )
#     165     final_outputs: Dict[str, Any] = self.prep_outputs(
#     166         inputs, outputs, return_only_outputs
#     167     )
#     168 except BaseException as e:
#
# File ~/devel/ai-agents/.venv/lib/python3.12/site-packages/langchain/chains/llm.py:126, in LLMChain._call(self, inputs, run_manager)
#     121 def _call(
#     122     self,
#     123     inputs: Dict[str, Any],
#     124     run_manager: Optional[CallbackManagerForChainRun] = None,
#     125 ) -> Dict[str, str]:
# --> 126     response = self.generate([inputs], run_manager=run_manager)
#     127     return self.create_outputs(response)[0]
#
# File ~/devel/ai-agents/.venv/lib/python3.12/site-packages/langchain/chains/llm.py:135, in LLMChain.generate(self, input_list, run_manager)
#     129 def generate(
#     130     self,
#     131     input_list: List[Dict[str, Any]],
#     132     run_manager: Optional[CallbackManagerForChainRun] = None,
#     133 ) -> LLMResult:
#     134     """Generate LLM result from inputs."""
# --> 135     prompts, stop = self.prep_prompts(input_list, run_manager=run_manager)
#     136     callbacks = run_manager.get_child() if run_manager else None
#     137     if isinstance(self.llm, BaseLanguageModel):
#
# File ~/devel/ai-agents/.venv/lib/python3.12/site-packages/langchain/chains/llm.py:197, in LLMChain.prep_prompts(self, input_list, run_manager)
#     195 for inputs in input_list:
#     196     selected_inputs = {k: inputs[k] for k in self.prompt.input_variables}
# --> 197     prompt = self.prompt.format_prompt(**selected_inputs)
#     198     _colored_text = get_colored_text(prompt.to_string(), "green")
#     199     _text = "Prompt after formatting:\n" + _colored_text
#
# File ~/devel/ai-agents/.venv/lib/python3.12/site-packages/langchain_core/prompts/chat.py:785, in BaseChatPromptTemplate.format_prompt(self, **kwargs)
#     776 def format_prompt(self, **kwargs: Any) -> PromptValue:
#     777     """Format prompt. Should return a PromptValue.
#     778
#     779     Args:
#    (...)
#     783         PromptValue.
#     784     """
# --> 785     messages = self.format_messages(**kwargs)
#     786     return ChatPromptValue(messages=messages)
#
# File ~/devel/ai-agents/.venv/lib/python3.12/site-packages/langchain_core/prompts/chat.py:1228, in ChatPromptTemplate.format_messages(self, **kwargs)
#    1224     result.extend([message_template])
#    1225 elif isinstance(
#    1226     message_template, (BaseMessagePromptTemplate, BaseChatPromptTemplate)
#    1227 ):
# -> 1228     message = message_template.format_messages(**kwargs)
#    1229     result.extend(message)
#    1230 else:
#
# File ~/devel/ai-agents/.venv/lib/python3.12/site-packages/langchain_core/prompts/chat.py:246, in MessagesPlaceholder.format_messages(self, **kwargs)
#     241 if not isinstance(value, list):
#     242     msg = (
#     243         f"variable {self.variable_name} should be a list of base messages, "
#     244         f"got {value} of type {type(value)}"
#     245     )
# --> 246     raise ValueError(msg)
#     247 value = convert_to_messages(value)
#     248 if self.n_messages:
#
# ValueError: variable history should be a list of base messages, got  of type <class 'str'>

# %% [markdown]
# #### Use conversation memory to derive more context from
#
# When I first ran through this I got the old: `BadRequestError: Error code: 400 - {'error': {'message': "This model's maximum context length is 16385 tokens.`
#
# And I realized I never even selected which model to use. LangChain was deciding for me... GPT 3... had to give that an override to get the next bit to work...

# %%
memory_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful Wikipedia historian."),
    MessagesPlaceholder(variable_name="history"),
    ("human", "{input}")
])

# todays_memory = load_memory()
memory_conversation = ConversationChain(
    llm=llm,
    memory=trending_conversation.memory,
    prompt=memory_prompt,
    verbose=True
)

for article in article_list:
    print(f"Analyzing {title}")

    title = article['title']
    text = article['text']

    memory_prompt = f"Does {title} relate to any other trending article? If yes, tell me why in 1 or 2 sentences."

    response = memory_conversation.predict(input=memory_prompt)
    print("memorycontext:", response)
    
    article['memorycontext'] =  response
# Out:
# Analyzing Pan_Am_Flight_103
#
#
# > Entering new ConversationChain chain...
# Prompt after formatting:
# System: You are a helpful Wikipedia historian.
# Human: Act as a professional news summarizer. Based on your knowledge of Jeff_Baena and the following extract. In 1 concise and confident sentence, explain why the Jeff_Baena article might be trending on Wikipedia on #2025-01-05 10:56:07.753157:
#
# {{Short description|American screenwriter and film director (1977–2025)|bot=PearBOT 5}}
# {{pp-protected|small=yes}}
# {{Use mdy dates|date=January 2025}}
# {{Use American English|date=January 2025}}
# {{Infobox person
# | image              = Jeff Baena.jpg
# | caption            = Baena at the 2017 [[Seattle International Film Festival]]
# | alt                = Baena posing
# | birth_name         = Jeffrey Baena
# | birth_date         = {{birth date|1977|6|29}}
# | birth_place        = [[Miami]], Florida, U.S.
# | death_date         = {{death date and age|2025|01|03|1977|06|29}}
# | death_place        = Los Angeles, California, U.S.
# | education          = [[New York University]]
# | occupation         = {{Flat list|
# * Director
# * screenwriter
# }}
# | years_active       = 2004–2025
# | spouse             = {{marriage|[[Aubrey Plaza]]|2021}}<ref name="bbc" />
# }}
#
# '''Jeffrey Baena''' (June 29, 1977 – January 3, 2025) was an American screenwriter and film director. He wrote and directed ''[[Life After Beth]]'' (2014), ''[[Joshy]]'' (2016), ''[[The Little Hours]]'' (2017), ''[[Horse Girl]]'' (2020) and ''[[Spin Me Round]]'' (2022) and co-wrote ''[[I Heart Huckabees]]'' (2004). He was known for his frequent collaborations with actresses [[Alison Brie]] (with whom he co-wrote ''Horse Girl'' and ''Spin Me Round''), [[Molly Shannon]], and [[Aubrey Plaza]].
#
# == Early life and education ==
# Baena was born on June 29, 1977,<ref name="Igoe">{{Cite web |last=Igoe |first=Katherine J. |date=January 17, 2023 |title=Aubrey Plaza's Low-Key Husband Jeff Baena Is So Supportive and Cute |url=https://www.aol.com/aubrey-plazas-low-key-husband-200900350.html |access-date=January 4, 2025 |website=[[Cosmopolitan (magazine)|Cosmopolitan]] |language=en-US |via=[[AOL]]}}</ref> and grew up in a [[Jewish secularism|secular Jewish]] family in [[Miami]].<ref>{{cite news |last=Lindner |first=Emmett |date=January 4, 2025 |title=Jeff Baena, Film Director and Screenwriter, Dies at 47 |url=https://www.nytimes.com/2025/01/04/arts/jeff-baena-dead.html |url-access=limited |accessdate=January 4, 2025 |newspaper=[[The New York Times]]}}</ref><ref>{{cite magazine |last1=Russell |first1=Anna |date=June 26, 2017 |title=Jeff Baena and Aubrey Plaza's Medieval Adventure |url=https://www.newyorker.com/magazine/2017/07/03/jeff-baena-and-aubrey-plazas-medieval-adventure#:~:text=Baena%20grew%20up%20in%20a%20secular%20Jewish%20household%20in%20Miami. |magazine=The New Yorker}}</ref> He graduated from the [[New York University Tisch School of the Arts]] with a degree in film and moved to [[Los Angeles]] to pursue directing.<ref name="bbc">{{cite web |title=Filmmaker Jeff Baena, husband of Aubrey Plaza, dead at 47 |url=https://www.bbc.com/news/articles/cvgny622w0zo |website=BBC |access-date=January 4, 2025 |date=January 4, 2025}}</ref>
#
# == Career ==
# Baena became a production assistant for filmmaker [[Robert Zemeckis]] on ''[[What Lies Beneath]]'' and ''[[Cast Away]]'' (both 2000).<ref name="Zax">{{Cite news |last=Zax |first=David |date=February 3, 2016 |title=How A Freak Eye Injury Became A Career Turning Point For The Director Of ''Joshy'' |url=http://www.fastcompany.com/3056144/most-creative-people/how-a-freak-eye-injury-became-a-career-turning-point-for-the-director-o |archive-url=http://web.archive.org/web/20161003150842/https://www.fastcompany.com/3056144/most-creative-people/how-a-freak-eye-injury-became-a-career-turning-point-for-the-director-o |archive-date=October 3, 2016 |access-date=February 3, 2016 |work=[[Fast Company]] |language=en-US}}</ref><ref>{{cite web|url=https://www.networkisa.org/creative-screenwriting/view/outline-over-screenplay-jeff-baena-on-spin-me-round-interview|title='Outline Over Screenplay' Jeff Baena On 'Spin Me Round Interview'|date=December 19, 2022|website=International Screenwriters' Association|access-date=January 4, 2025}}</ref> After working with Zemeckis, Baena became an assistant editor for writer-director [[David O. Russell]]. After a year and a half of working together, a minor car accident injured one of Baena's eyes. Partially to keep his spirits up and pass the time during his recovery, Russell began discussing story ideas with Baena. The two ended up collaborating on four scripts together, including ''[[I Heart Huckabees]]'', which Russell directed in 2004, and [[Jay Roach]]'s ''[[Meet the Fockers]]'' (also 2004), for which they made uncredited revisions.<ref name="Zax" /><ref>{{cite web|url=https://norman.hrc.utexas.edu/fasearch/findingaid.cfm?eadid=00481&kw=de%20niro|title=Robert De Niro: A Preliminary Inventory of His Papers at the Harry Ransom Center|publisher=[[Harry Ransom Center]]|via=[[University of Texas at Austin]]|access-date=January 4, 2025}}</ref>{{rp|146–147}}
#
# Baena had planned for the comedy-drama ''[[Joshy]]'' to be his directorial debut, but actor and collaborator [[Adam Pally]] had to postpone due to personal reasons. He then decided to work on the zombie comedy ''[[Life After Beth]]'', from a script he started writing in 2003
# AI: The Jeff_Baena article might be trending on Wikipedia on January 5, 2025, following his recent death on January 3, 2025, at the age of 47, as an American screenwriter and film director known for works like ''Life After Beth'' and his collaborations with actresses Alison Brie, Molly Shannon, and Aubrey Plaza.
# Human: Act as a professional news summarizer. Based on your knowledge of Aubrey_Plaza and the following extract. In 1 concise and confident sentence, explain why the Aubrey_Plaza article might be trending on Wikipedia on #2025-01-05 10:56:07.753157:
#
# {{Short description|American actress and producer (born 1984)}}
# {{pp-protected|small=yes}}
# {{Use mdy dates|date=December 2024}}{{Use American English|date=January 2025}}
#
# {{Infobox person
# | image = Aubrey Plaza at the 2024 Cannes Film Festival (cropped).jpg
# | caption      = Plaza at the [[Cannes Film Festival]] in 2024
# | birth_name   = Aubrey Christina Plaza
# | birth_date   = {{Birth date and age|1984|6|26}}
# | birth_place  = [[Wilmington, Delaware]], U.S.
# | alma_mater   = [[New York University]] ([[Bachelor of Fine Arts|BFA]])
# | occupation   = {{hlist|Actress|comedian|producer}}
# | years_active = 2004–present
# | works        = [[Aubrey Plaza filmography|Full list]]
# | spouse       = {{marriage|[[Jeff Baena]]|2021|2025|end=his death}}
# }}
# '''Aubrey Christina Plaza''' (born June 26, 1984) is an American actress, comedian, and producer. She began acting in local theater productions as a teenager and performed [[Improvisational theatre|improv]] and [[sketch comedy]] at the [[Upright Citizens Brigade Theatre]]. After graduating from [[New York University Tisch School of the Arts]], Plaza made her feature film debut in ''[[Mystery Team]]'' (2009) and gained wide recognition for her role as [[April Ludgate]] on the [[NBC]] political satire [[sitcom]] ''[[Parks and Recreation]]'' (2009–2015).
#
# In film, Plaza had a supporting role in ''[[Scott Pilgrim vs. the World]]'' (2010) and a leading role in ''[[Safety Not Guaranteed]]'' (2012). From 2017 to 2019, Plaza portrayed the [[Shadow King]] and [[List of Legion characters#Lenny Busker|Lenny Busker]] in the critically praised [[FX (TV channel)|FX]] superhero series ''[[Legion (TV series)|Legion]]'', and produced and starred in the 2017 black comedy films ''[[The Little Hours]]'' and ''[[Ingrid Goes West]]''. She also starred in the romantic comedy ''[[Happiest Season]]'' and thriller ''[[Black Bear (film)|Black Bear]]'' (both 2020) as well as produced and played the title character in the crime film ''[[Emily the Criminal]]'' (2022).
#
# Plaza received nominations for a [[Primetime Emmy Awards]] and a [[Golden Globe Awards|Golden Globe Award]] for her role as a strait-laced lawyer in the [[The White Lotus season 2|second season]] of the [[HBO]] anthology series ''[[The White Lotus]]'' (2022). ''[[Time (magazine)|Time]]'' magazine named her one of the [[Time 100|100 most influential people in the world]] in 2023.<ref name="Time"/> In 2024, she starred as [[Rio Vidal]] in the [[Marvel Cinematic Universe]] miniseries ''[[Agatha All Along (miniseries)|Agatha All Along]]''.
#
# ==Early life and education==
# Aubrey Christina Plaza was born on June 26, 1984, in [[Wilmington, Delaware]].<ref name="NYTG">{{cite web|url=https://www.newyorktheatreguide.com/stars-on-stage/aubrey-plaza|title=Aubrey Plaza On Stage|website=New York Theatre Guide|access-date=June 28, 2024|archive-url=https://web.archive.org/web/20240108110845/https://www.newyorktheatreguide.com/stars-on-stage/aubrey-plaza|archive-date=January 8, 2024|url-status=live}}</ref> The eldest of three sisters,<ref name="DelawareToday">{{cite magazine |url=http://www.delawaretoday.com/Delaware-Today/March-2012/Aubrey-Plaza-of-NBCs-Parks-and-Recreation-Wilmington-Native-Is-Building-a-Buzz-in-Hollywood/ |title=Aubrey Plaza of NBC's 'Parks and Recreation': Wilmington Native is Building a Buzz in Hollywood |first=John Jr. |last=Micklos |date=February 15, 2012 |magazine=Delaware Today |access-date=May 13, 2012 |archive-date=September 23, 2015 |archive-url=https://web.archive.org/web/20150923213442/http://www.delawaretoday.com/Delaware-Today/March-2012/Aubrey-Plaza-of-NBCs-Parks-and-Recreation-Wilmington-Native-Is-Building-a-Buzz-in-Hollywood/ |url-status=live}}</ref> she was born when her parents, Bernadette M. and David Plaza, were 19 and 20. They worked various jobs to make ends meet and attended night school in pursuit of their respective professional qualifications to become an attorney and financial advisor.<ref name="DO">{{cite web |url=http://blogs.delawareonline.com/pulpculture/2010/01/15/from-wilmy-to-hollywood/ |title=From Wilmy to Hollywood |last=Cormier |first=Ryan |date=January 15, 2010 |website=[[The News Journal]] |access-date=May 21, 2012 |archive-date=April 22, 2017 |archive-url=https://web.archive.org/web/20170422161029/http://blogs.delawareonline.com/pulpculture/2010/01/15/from-wilmy-to-hollywood/ |url-status=dead}}</ref><ref name="TG 22"/><ref name="LAT 22"/> Plaza was inspired by their work ethic: "My parents are very ambitious and they came from nothing ... They were hustlers, so I think I have that in my blood".<ref name="TG 22"/><ref name="People 23">{{cite web|url=https://people.com/all-about-aubrey-plaza-parents-8391900|title=All About Aubrey Plaza's Parents, David and Bernadette Plaza|work=People|date=November 23, 2023|access-date=June 29, 2024}}</ref> Her paternal grandfather was born in [[Arecibo, Puerto Rico]], and moved to the [[Stateside Puerto Ricans|mainland US]] when he was 17 years old.<ref name="DelawareOnl
# AI: The Aubrey_Plaza article might be trending on Wikipedia on January 5, 2025, following the recent passing of her husband, Jeff Baena, on January 3, 2025, and the public's interest in both their careers and personal lives.
# Human: Act as a professional news summarizer. Based on your knowledge of Squid_Game_season_2 and the following extract. In 1 concise and confident sentence, explain why the Squid_Game_season_2 article might be trending on Wikipedia on #2025-01-05 10:56:07.753157:
#
# {{Short description|Season of Korean television series}}
# {{Infobox television season
# | season_number        = 2
# | bgcolour             = #FF9F80
# | image                = Squid Game season 2 poster.png
# | image_upright        = 1
# | image_alt            = Korean promotional poster featuring notable characters running away in a carousel-themed location with dead people on the ground
# | caption              = Promotional poster
# | showrunner           = [[Hwang Dong-hyuk]]
# | starring             = {{Plainlist|
# * [[Lee Jung-jae]]
# * [[Lee Byung-hun]]
# * [[Wi Ha-joon]]
# * [[Im Si-wan]]
# * [[Kang Ha-neul]]
# * [[Lee Jin-wook]]
# * [[Park Sung-hoon]]
# * [[Yang Dong-geun]]
# * [[Jo Yu-ri]]
# * [[Kang Ae-shim]]
# * {{Ill|Lee Seo-hwan|ko|이서환}}
# * [[Park Gyu-young]]
# }}
# | network              = [[Netflix]]
# | num_episodes         = 7
# | released             = {{Start date|2024|12|26}}
# | next_season          =
# }}
#
# The second season of the South Korean [[Utopian and dystopian fiction|dystopian]] survival [[Thriller (genre)#Television|thriller]] television series ''[[Squid Game]]'', marketed as '''''Squid Game 2''''', is created by Korean television producer and writer [[Hwang Dong-hyuk]]. It was released on [[Netflix]] on December 26, 2024.
#
# The season stars [[Lee Jung-jae]], [[Lee Byung-hun]], [[Wi Ha-joon]], [[Im Si-wan]], [[Kang Ha-neul]], [[Lee Jin-wook]], [[Park Sung-hoon]], [[Yang Dong-geun]], [[Jo Yu-ri]], [[Kang Ae-shim]], {{Ill|Lee Seo-hwan|ko|이서환}}, and [[Park Gyu-young]]. Set three years after the first season, the story focuses on [[Seong Gi-hun]]'s life after winning the Squid Game, giving up on going to the United States and returning to the games with a new resolution in mind. He once again dives into the mysterious survival game, starting another life-or-death game with new participants gathered to win the prize of {{KRW|45.6|link=yes}}{{nbsp}}billion ({{USD|31.1|link=yes}}{{nbsp}}million). A side-plot of the season sees [[Hwang Jun-ho (character)|Hwang Jun-ho]] trying to locate Gi-hun with help from hired mercenaries.
#
# The season garnered positive reviews from critics. The [[Squid Game season 3|third and final season]] is confirmed to be released in 2025, which was filmed back-to-back with the second season.
#
# == Episodes ==
# <onlyinclude>{{Episode table |background=#FF9F80 |overall=5 |season=5 |title=43 |director=14 |writer=17 |airdate=16 |released=y |airdateR=<ref name="Season2Release">{{Cite web |last=Porter |first=Rick |date=July 31, 2024 |title='Squid Game' to End With Season 3, Post-Christmas Return Set at Netflix |url=https://www.hollywoodreporter.com/tv/tv-news/squid-game-season-2-premiere-ending-season-3-1235963660/ |url-status=live |archive-url=https://web.archive.org/web/20241128194715/https://www.hollywoodreporter.com/tv/tv-news/squid-game-season-2-premiere-ending-season-3-1235963660/ |archive-date=November 28, 2024 |access-date=July 31, 2024 |website=[[The Hollywood Reporter]]}}</ref> |episodes={{Episode list/sublist|Squid Game season 2
# | EpisodeNumber   = 10
# | EpisodeNumber2  = 1
# | Title           = Bread and Lottery
# | NativeTitle     = 빵과 복권
# | TranslitTitle   = Ppang-gwa Bokgwon
# |NativeTitleLangCode = ko
# | DirectedBy      = [[Hwang Dong-hyuk]]
# | WrittenBy       = Hwang Dong-hyuk
# | OriginalAirDate = {{Start date|2024|12|26}}
# | ShortSummary    = Seong Gi-hun leaves the terminal{{Efn|As depicted in the [[Squid Game season 1|first season]] episode "One Lucky Day".}} determined to confront the Front Man behind the games. Realizing he is being monitored, he removes a tracking device implanted behind his ear. Hwang Jun-ho survives his fall from the cliff.{{Efn|As depicted in the first season episode "Front Man".}} Two years later, Gi-hun works with Kim, his former [[loan shark]], and his lackeys to track down the games' recruiter in Seoul. Kim and his associate, Choi Woo-seok, eventually locate the recruiter and watch him offer vagrants bread or a lottery ticket; most choose the ticket, and the recruiter destroys the rejected bread in front of them. The recruiter abducts Kim and Woo-seok and forces them to play a deadly game of [[rock paper scissors]] minus one combined with [[Russian roulette]], resulting in Kim's death. Jun-ho investigates Gi-hun and locates his operational base. The recruiter confronts Gi-hun there, revealing he was once a soldier in the games who killed his own father, a player, and justifies the games' cruelty by vilifying the participants as scum. He challenges Gi-hun into a round of Russian roulette, resulting in his own death.
# | LineColor       = FF9F80
# }}
# {{Episode list/sublist|Squid Game season 2
# | EpisodeNumber   = 11
# | EpisodeNumber2  = 2
# | Title           = Halloween Party
# | NativeTitle     = 할로윈 파티
# | TranslitTitle   = Hallowin Pati
# |NativeTitleLangCode = ko
# | DirectedBy      = Hwang Dong-hyuk
# | WrittenBy       = Hwang Dong-hyuk
# | OriginalAirDate = {{Start date|2024|12|26}}
# | ShortSummary    = Gi-hun, Jun-ho, and Woo-seok discover a lead from the recruiter's jacket pointing to a Hal
# AI: The Squid_Game_season_2 article might be trending on Wikipedia on January 5, 2025, due to the recent release of the highly anticipated second season of the South Korean dystopian survival thriller television series "Squid Game," which has captured the attention of fans and critics alike with its intense storyline and stellar cast.
# Human: Act as a professional news summarizer. Based on your knowledge of Human_metapneumovirus and the following extract. In 1 concise and confident sentence, explain why the Human_metapneumovirus article might be trending on Wikipedia on #2025-01-05 10:56:07.753157:
#
# {{Short description|Species of virus belonging to family pneumoviridae}}
# {{Virusbox
# | image = Pathogens-04-00682-g001.png
# | image_alt =
# | image_caption = ''Human metapneumovirus'' (hMPV) structure and genome
# | parent = Metapneumovirus
# | species = Human metapneumovirus
# | synonyms =
# | synonyms_ref =
# }}
#
# '''''Human metapneumovirus''''' ('''HMPV''' or '''hMPV''') is a [[negative-sense single-stranded RNA virus]] of the family ''[[Pneumoviridae]]''<ref name="ICTVReport">{{cite web|title=ICTV Online (10th) Report|url=http://www.ictv.global/report/pneumoviridae}}</ref> and is closely related to the ''[[Avian metapneumovirus]]'' (AMPV) subgroup C. It was isolated for the first time in 2001 in the [[Netherlands]] by using the RAP-PCR (RNA arbitrarily primed [[Polymerase chain reaction|PCR]]) technique for identification of unknown viruses growing in cultured cells.<ref name=":1">{{Cite journal|last1=van den Hoogen|first1=Bernadette G.|last2=Jong|first2=Jan C. de|last3=Groen|first3=Jan|last4=Kuiken|first4=Thijs|last5=Groot|first5=Ronald de|last6=Fouchier|first6=Ron A.M.|last7=Osterhaus|first7=Albert D.M.E.|title=A newly discovered human pneumovirus isolated from young children with respiratory tract disease|journal=Nature Medicine|volume=7|issue=6|pages=719–724|doi=10.1038/89098|pmid=11385510|year=2001|pmc=7095854}}</ref> As of 2016, it was the second most common cause (after [[respiratory syncytial virus]] (RSV)) of acute [[respiratory tract infection|respiratory tract illness]] in otherwise-healthy children under the age of 5 in a large US [[outpatient clinic]].<ref name=":0">{{Cite journal|last1=Williams|first1=John V.|last2=Harris|first2=Paul A.|last3=Tollefson|first3=Sharon J.|last4=Halburnt-Rush|first4=Lisa L.|last5=Pingsterhaus|first5=Joyce M.|last6=Edwards|first6=Kathryn M.|last7=Wright|first7=Peter F.|last8=Crowe|first8=James E. Jr.|date=2004-01-29|title=Human Metapneumovirus and Lower Respiratory Tract Disease in Otherwise Healthy Infants and Children|journal=New England Journal of Medicine|volume=350|issue=5|pages=443–450|doi=10.1056/nejmoa025472|issn=0028-4793|pmid=14749452|pmc=1831873}}</ref>
#
# The peak age of hospitalization for infants with HMPV occurs between 6–12 months of age, slightly older than the peak of RSV, which is around 2–3 months. The clinical features and severity of HMPV are similar to those of RSV. HMPV is also an important cause of disease in older adults and infants.
#
# {{As of|2025|1}}, an outbreak of HMPV is in progress in [[China]].<ref>{{Cite news |date=2025-01-06 |title=HMPV is here: India detects its first case in Bengaluru with 2 cases from karnataka |url=https://economictimes.indiatimes.com/news/india/hmpv-is-here-india-detects-its-first-case-in-bengaluru/articleshow/116980492.cms |access-date=2025-01-06 |work=The Economic Times |issn=0013-0389}}</ref>
#
# ==Taxonomy==
# {| class="sortable wikitable"
# |+ Genus ''Metapneumovirus'': species and their viruses<ref name=ICTVReport /><ref>{{Cite journal|last1=Amarasinghe|first1=Gaya K.|last2=Bào|first2=Yīmíng|last3=Basler|first3=Christopher F.|last4=Bavari|first4=Sina|last5=Beer|first5=Martin|last6=Bejerman|first6=Nicolás|last7=Blasdell|first7=Kim R.|last8=Bochnowski|first8=Alisa|last9=Briese|first9=Thomas|date=2017-04-07|title=Taxonomy of the order Mononegavirales: update 2017 |journal=Archives of Virology|volume=162|issue=8|pages=2493–2504|doi=10.1007/s00705-017-3311-7 |pmid=28389807|pmc=5831667}}</ref>
# |-
# !Genus
# !Species
# !Virus (abbreviation)
# !NCBI taxonomy ID
# |- style="vertical-align:top"
# | rowspan="2" | ''Metapneumovirus''
# | rowspan="1" | ''Avian metapneumovirus''
# | rowspan="1" | avian metapneumovirus (AMPV)
# | rowspan="1" | [https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?mode=Info&id=38525 38525]
# |- style="vertical-align:top"
# | rowspan="1" | ''Human metapneumovirus''
# | rowspan="1" | human metapneumovirus (HMPV)
# | rowspan="1" | [https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?mode=Info&id=162145 162145]
# |}
#
# ==Discovery and naming==
# Human metapneumovirus was first discovered in 2001 in the Netherlands by Bernadette G. van den Hoogen and her colleagues.<ref name="kahn46">{{cite journal |last1=Kahn |first1=Jeffrey S. |title=Epidemiology of Human Metapneumovirus |journal=Clinical Microbiology Reviews |date=July 2006 |volume=19 |issue=3 |pages=546–557 |doi=10.1128/cmr.00014-06 |pmid=16847085 |pmc=1539100 }}</ref><ref name="cdc47">{{cite web |title=Human Metapneumovirus |url=https://www.cdc.gov/ncird/human-metapneumovirus.html |website=Centers for Disease Control and Prevention |date=13 April 2023 }}</ref><ref name="cc48">{{cite web |title=Human Metapneumovirus (HMPV): Causes & Treatment |url=https://my.clevelandclinic.org/health/diseases/22443-human-metapneumovirus-hmpv |website=Cleveland Clinic }}</ref><ref name="verena49">{{cite journal |title=Human Metapneumovirus: Lessons Learned over the First Decade |journal=Clinical Microbiology Reviews |date=Oct 2011 |volume=24 |issue=4 |pages=734–754 |doi=10.1128/cmr.00015-11 |
# AI: The Human_metapneumovirus article might be trending on Wikipedia on January 5, 2025, due to an ongoing outbreak of HMPV in China, as reported by The Economic Times, raising public interest and concern about the virus and its impact on public health.
# Human: Act as a professional news summarizer. Based on your knowledge of Nosferatu_(2024_film) and the following extract. In 1 concise and confident sentence, explain why the Nosferatu_(2024_film) article might be trending on Wikipedia on #2025-01-05 10:56:07.753157:
#
# {{pp|small=yes}}
# {{Short description|2024 American supernatural Gothic horror film by Robert Eggers}}
# {{Use American English|date=November 2024}}
# {{Use mdy dates|date=November 2024}}
# {{Infobox film
# | image          = Nosferatu IMAX poster 2024.jpg
# | caption        = Theatrical release poster
# | director       = [[Robert Eggers]]
# | producer       = {{Plainlist|
# * Jeff Robinov
# * John Graham
# * [[Chris Columbus (filmmaker)|Chris Columbus]]
# * Eleanor Columbus
# * Robert Eggers
# }}
# | screenplay     = Robert Eggers
# | based_on       = {{based_on|''[[Nosferatu]]''|[[Henrik Galeen]]}}<br/>
# | starring       = {{Plainlist|
# * [[Bill Skarsgård]]
# * [[Nicholas Hoult]]
# * [[Lily-Rose Depp]]
# * [[Aaron Taylor-Johnson]]
# * [[Emma Corrin]]
# * [[Willem Dafoe]]
# }}
# | music          = Robin Carolan
# | cinematography = [[Jarin Blaschke]]
# | editing        = Louise Ford
# | production_companies = {{Plainlist|
# * Maiden Voyage Pictures
# * [[Studio 8 (company)|Studio 8]]
# * Birch Hill Road Entertainment
# }}
# | distributor    = {{plainlist|
# * [[Focus Features]] (United States)
# * [[Universal Pictures]] (International)<ref name="deadline">{{cite web |last=Kroll |first=Justin |title=Aaron Taylor-Johnson Joins Robert Eggers' ''Nosferatu'' Movie For Focus |url=https://deadline.com/2023/03/aaron-taylor-johnson-robert-eggers-nosferatu-focus-1235277625/ |website=[[Deadline Hollywood]] |access-date=March 3, 2023 |date=March 3, 2023 |archive-date=March 3, 2023 |archive-url=https://web.archive.org/web/20230303192032/https://deadline.com/2023/03/aaron-taylor-johnson-robert-eggers-nosferatu-focus-1235277625/ |url-status=live }}</ref>
# }}
# | released       = {{Film date|2024|12|02|Berlin|2024|12|25|United States}}
# | runtime        = 132 minutes<ref>{{Cite web|date=November 20, 2024|title=''Nosferatu'' (15)|url=https://www.bbfc.co.uk/release/nosferatu-q29sbgvjdglvbjpwwc0xmdiynde1|access-date=November 24, 2024|website=[[British Board of Film Classification|BBFC]]}}</ref>
# | country        = United States
# | language       = {{Plainlist|
# * English<ref name="bbfc">{{cite web |title=Nosferatu |url=https://www.bbfc.co.uk/release/nosferatu-q29sbgvjdglvbjpwwc0xmdiynde1 |website=BBFC}}</ref>
# * German
# * Romanian
# * Russian
# }}
# | budget         = $50 million<ref name="DeadlineProj"/>
# | gross          = $100.4 million<ref name="BOM">{{Cite Box Office Mojo|title=Nosferatu|id=tt5040012|website=[[Box Office Mojo]]|access-date=January 5, 2025}}</ref><ref name="NUM">{{Cite web |title=Nosferatu – Financial Information |url=https://www.the-numbers.com/movie/Nosferatu-(2024)#tab=summary|website=[[The Numbers (website)|The Numbers]]|access-date=January 5, 2025}}</ref>
# }}
#
# '''''Nosferatu''''' is a 2024 American [[Gothic film|gothic]] [[supernatural horror film]]<ref>{{Cite web |title=Nosferatu (2024) {{!}} Rotten Tomatoes |url=https://www.rottentomatoes.com/m/nosferatu_2024 |access-date=2025-01-06 |website=www.rottentomatoes.com |language=en}}</ref> written and directed by [[Robert Eggers]]. It is a remake of [[F. W. Murnau]]'s 1922 [[silent film]] ''[[Nosferatu]]'', itself inspired by [[Bram Stoker]]'s 1897 novel ''[[Dracula]]''. The film stars [[Bill Skarsgård]] as the titular character and [[Nicholas Hoult]] and [[Lily-Rose Depp]] as the married Hutter couple, with [[Aaron Taylor-Johnson]], [[Emma Corrin]], [[Ralph Ineson]], [[Simon McBurney]], and [[Willem Dafoe]] in supporting roles.
#
# Development on the film began in 2015 when Eggers planned to make it his second film, describing it as a passion project, but he eventually opted to delay its production. Skarsgård and Depp were cast as leads in September 2022. Filming took place primarily at [[Barrandov Studios]] in [[Prague]], [[Czech Republic]] between February and May 2023.
#
# ''Nosferatu'' had its world premiere in Berlin, Germany on December 2, 2024, and was theatrically released in the United States by [[Focus Features]] on December 25, 2024, and internationally by [[Universal Pictures]] on January 1, 2025. The film received generally positive reviews from critics and has grossed over $100 million worldwide.
#
# == Plot ==
# Under the cover of the night, a young girl named Ellen weeps as she prays, desperately seeking solace from an unseen spirit to ease her deep loneliness. Her plea is answered by a mysterious malevolent entity who attacks her, something Ellen initially finds pleasurable but then leaves her convulsing in a seizure.
#
# Years later in the winter of 1838, Ellen lives in the town of Wisborg, Germany, with her husband, Thomas Hutter, a solicitor and estate agent. Hoping to achieve financial security, Thomas accepts a commission from his employer, Herr Knock, to sell Schloss Grünewald, a decrepit stately home in Wisborg, to the reclusive and eccentric Count Orlok. Unbeknownst to Thomas, Knock has arranged this as part of an [[occult]] pact with Orlok.
#
# Ellen becomes fearful and asks Thomas to stay with her, confessing that, before their wedding, she dreamed she married Death himself, with only corpses in attendance, and found herse
# AI: The Nosferatu_(2024_film) article might be trending on Wikipedia on January 5, 2025, following the film's successful theatrical release in the United States and internationally, coupled with positive reviews from critics and its impressive worldwide box office gross of over $100 million.
# Human: Act as a professional news summarizer. Based on your knowledge of Jimmy_Carter and the following extract. In 1 concise and confident sentence, explain why the Jimmy_Carter article might be trending on Wikipedia on #2025-01-05 10:56:07.753157:
#
# {{Short description|President of the United States from 1977 to 1981}}
# {{Redirect|James Earl Carter|his father|James Earl Carter Sr.||James Carter (disambiguation){{!}}James Carter}}
# {{Pp-blp|small=yes}}
# {{Pp-move}}
# {{Good article}}
# {{Use American English|date=September 2024}}
# {{Use mdy dates|date=December 2024}}
# {{Infobox officeholder
# | name                = Jimmy Carter
# | image               = JimmyCarterPortrait (cropped).jpg
# | alt                 = Portrait of Jimmy Carter in a dark blue suit
# | caption             = Official portrait, 1978
# | order               = 39th
# | office              = President of the United States
# | vicepresident       = [[Walter Mondale]]
# | term_start          = January 20, 1977
# | term_end            = January 20, 1981
# | predecessor         = [[Gerald Ford]]
# | successor           = [[Ronald Reagan]]
# | order1              = 76th
# | office1             = Governor of Georgia
# | term_start1         = January 12, 1971
# | term_end1           = January 14, 1975
# | predecessor1        = [[Lester Maddox]]
# | successor1          = [[George Busbee]]
# | lieutenant1         = Lester Maddox
# | state_senate2       = Georgia State
# | district2           = [[Georgia's 14th Senate district|14th]]
# | term_start2         = January 14, 1963
# | term_end2           = January 9, 1967
# | predecessor2        = [[James M. Dykes]]
# | successor2          = [[Hugh Carter]]
# | birth_name          = James Earl Carter Jr.
# | birth_date          = {{Birth date|1924|10|01}}
# | birth_place         = [[Plains, Georgia]], U.S.
# | death_date          = {{Death date and age|2024|12|29|1924|10|01}}
# | death_place         = Plains, Georgia, U.S.
# | resting_place       = <!-- [[209 Woodland Drive]], Plains -->
# | party               = [[Democratic Party (United States)|Democratic]]
# | spouse              = {{marriage|[[Rosalynn Smith]]|July 7, 1946|November 19, 2023|end=died}}
# | children            = 4, including [[Jack Carter (politician)|Jack]] and [[Amy Carter|Amy]]
# | parents             = {{plainlist|
# * [[James Earl Carter Sr.]]
# * [[Bessie Lillian Gordy]]
# }}
# | relatives           = [[List of United States political families (C)#The Carters of Georgia|Carter family]]
# | education           = [[United States Naval Academy]] ([[Bachelor of Science|BS]])
# | awards              = [[List of awards and honors received by Jimmy Carter|Full list]]
# | signature           = Jimmy Carter Signature-2.svg
# | signature_alt       = Cursive signature in ink
# | branch              = [[United States Navy]]<!--No flags per MOS:INFOBOXFLAG-->
# | serviceyears        = {{plainlist|
# * 1946–1953 (active)
# * 1953–1961 (reserve)
# }}
# | rank                = [[Lieutenant (navy)|Lieutenant]]<!--No icons per MOS:INFOBOXFLAG-->
# | mawards             = {{plainlist|
# * [[American Campaign Medal]]
# * [[World War II Victory Medal]]
# * [[China Service Medal]]
# * [[National Defense Service Medal]]
# }}
# | battles             = [[United States Navy in World War II|World War II]]
# | module              = {{Listen voice
# |filename=Jimmy Carter speaks on the Soviet invasion of Afghanistan.ogg
# |description=Carter speaks on the [[Soviet invasion of Afghanistan]]
# |recorded=January 4, 1980}}
# }}
#
# '''James Earl Carter Jr.''' (October 1, 1924 – December 29, 2024) was the 39th [[president of the United States]], serving from 1977 to 1981. A member of the [[Democratic Party (United States)|Democratic Party]], Carter served as the 76th [[governor of Georgia]] from 1971 to 1975 and in the [[Georgia State Senate]] from 1963 to 1967. He was the [[List of presidents of the United States by age|longest-lived president in U.S. history]] and the first to reach the [[Centenarian|age of 100]].
#
# Born and raised in [[Plains, Georgia]], Carter graduated from the [[United States Naval Academy]] in 1946 and joined the [[United States Navy]]'s submarine service. He married [[Rosalynn Smith]], and they worked closely together throughout their lives. Carter returned home after his military service and revived his family's peanut-growing business. Opposing [[Racial segregation in the United States|racial segregation]], Carter supported the growing [[civil rights movement]] and became an activist within the Democratic Party. After serving in the Georgia State Senate and then as governor of Georgia, Carter [[Jimmy Carter 1976 presidential campaign|ran for president]] in [[1976 United States presidential election|1976]]. Initially a [[dark horse]] candidate not well known outside Georgia, he secured the Democratic nomination and selected [[Walter Mondale]] as his running mate. They narrowly defeated the [[Republican Party (United States)|Republican Party]]'s ticket of President [[Gerald Ford]] and Senator [[Bob Dole]].
#
# On his second day in office, Carter [[Proclamation 4483|pardoned all Vietnam War draft evaders]]. He created a national energy policy that included conservation, price control, and new technology. Carter successfully pursued the [[Camp David Accords]], the [[Panama Canal Treaties]], and the second round of [
# AI: The Jimmy_Carter article might be trending on Wikipedia on January 5, 2025, following the recent passing of the former U.S. president on December 29, 2024, at the age of 100, prompting increased public interest and awareness of his life and legacy.
# Human: Act as a professional news summarizer. Based on your knowledge of Brothers_Home and the following extract. In 1 concise and confident sentence, explain why the Brothers_Home article might be trending on Wikipedia on #2025-01-05 10:56:07.753157:
#
# {{Short description|1970s–1980s South Korean internment camp}}
# {{pp-vandalism|small=yes}}
# {{infobox organization
# |name                    = Brothers house
# |native_name         = 형제복지원
# |native_name_lang = ko
# |defunct                = 1988
# |image                   = File:BrothersHomeBusan.jpeg
# |image_size           = 250px
# |caption                 = Former facility in Busan, South Korea.
# |formation              = 1960
# |successor                  = Siloam's House<ref name="APJJF" />
# |location                 = {{ill|Jurye-dong|ko|주례동}}, [[Buk District, Busan|Buk District]] (now [[Sasang District]]), [[Busan]]
# |purpose                = [[Child protective services]], [[welfare spending|welfare]] <small>(officially)</small>
# |status                  =
# |leader_name      = Park In-guen
# |key_people         = [[Chun Doo-hwan]]
# {{Infobox Korean name|child=yes
# | title          =
# | hangul         = 형제복지원
# | hanja          = 兄弟福祉院
# | rr             = Hyeongje bokjiwon
# | mr             =Hyŏngje bokchiwŏn
# | koreanipa      =
# }}
# }}
# The '''Brothers' Home''' ({{Langx|ko|형제복지원}}) was an [[internment camp]] (officially a [[welfare spending|welfare]] facility) located in [[Busan]], South Korea during the 1970s and 1980s. The facility contained 20 factories and housed thousands of people, including homeless people and children taken from the streets, along with student protesters who opposed the government. Only 10% of internees were actually homeless.<ref name="aj-20211210">{{Cite web|date=10 December 2021|title=Secrets of South Korea's house of horrors hidden in Australia|url=https://www.aljazeera.com/features/2021/12/10/secrets-of-south-koreas-house-of-horrors-hidden-in-australia|last=Kim|first=Susan|access-date=15 December 2021|work=Al Jazeera}}</ref> The camp was home to some of the worst [[human rights in South Korea|human rights abuses in South Korea]] during the period<ref>{{cite web|url=https://edition.cnn.com/videos/world/2016/08/24/hancocks-brothers-home-human-rights-abuse-pkg.cnn|title=Child victims of Brothers Home still search for justice|work=CNN|date=24 August 2016|access-date=26 June 2022}}</ref> and has been nicknamed "Korea's [[Auschwitz concentration camp|Auschwitz]]" by various Korean media outlets.<ref>Multiple sources:
# * {{cite web|newspaper=[[The Hankyoreh]]|script-title=ko:[단독] '한국판 아우슈비츠' 형제복지원 특별법 곧 재발의|author=박수지|url=https://www.hani.co.kr/arti/society/rights/646133.html#cb|language=ko|date=September 7, 2014}}
# * {{cite web|script-title=ko:한국의 '아우슈비츠' 형제복지원‥657명 사망 첫 확인|newspaper=[[MBC TV (South Korean TV channel)|MBC]]|url=https://imnews.imbc.com/replay/2022/nwdesk/article/6401308_35744.html|date=August 24, 2022|language=ko|author=윤수한}}
# * {{cite web|script-title=ko:35년 만에 드러난 '한국판 아우슈비츠'의 진상... 정부가 묵인한 '국가 범죄'였다|url=https://www.segye.com/newsView/20220824521000|date=August 25, 2022|newspaper=[[Segye Ilbo]]|author=백준무|language=ko}}
# * {{cite web|script-title=ko:'한국판 아우슈비츠' 형제복지원, 30년 만에 다시 심판대...배상길 열리나|url=https://www.donga.com/news/list/article/all/20181120/92950950/1|newspaper=[[The Dong-A Ilbo]]|author=뉴스1|language=ko|date=November 20, 2018}}</ref>
#
# ==Background==
# Throughout the 1950s, the Republic of Korea struggled to recover from the devastation of the [[Korean War]].<ref name="THK" /> Welfare policies during this period were focused on the housing of [[orphan]]s, as they were seen as a stain to South Korea's national reputation.<ref name=":0" />{{rp|p=175}} As the 1960s unfolded, [[Park Chung Hee]]'s military junta commenced efforts to 'cleanse' society of those who were seen as "symbols of the 'poverty' and 'disorder' of cities",<ref name="APJJF">{{cite web |author1=Hae-nam Park |author2=Il-hwan Kim |author3=Jae-hyung Kim |author4=Ji-hyun Choo |author5=Jong-sook Choi |author6=Jun-chol So |author7=Kwi-byung Kwak |author8=Sang-jic Lee |date=June 15, 2023 |title='Big Brother' at Brothers Home: Exclusion and Exploitation of Social Outcasts in South Korea |url=https://apjjf.org/2023/6/kim-et-al |website=[[The Asia-Pacific Journal: Japan Focus]]}}</ref> and these policies were expanded to cover the detention of general [[Vagrancy|vagrants]].<ref name=":0" />{{rp|p=176}}{{efn|South Korean law during this period defined 'vagrants' ({{Korean|hangul=부랑인|hanja=浮浪人}}) as "beggars, gum sellers, or street hustlers who, without a fixed residence, wanders around places where many people gather or pass by, such as tourist spots, hospitality establishments, train stations, bus stops, or residential areas, and harasses passersby by begging or forcefully selling items."<ref>{{cite web|quote="일정한 주거 없이 관광업소, 접객업소, 역, 버스정류소 등 많은 사람들이 모이거나 통행하는 곳과 주택가를 배회하거나 좌정하여 구걸 또는 물품을 강매함으로써 통행인을 괴롭히는 걸인, 껌팔이, 앵벌이." 이들은 우리 법이 '부랑인'이라 정의했던 대상이다.|title=(5)명랑사회를 위한 '부랑인 청소'...결국 우리도 공모자였다|url=https://m.khan.co.kr/national/national-general/article/201706182059005#c2b|date=June 18, 2017|author=이소영|newspaper=[[Kyunghyang Shinmun]]|language=ko}}</ref> In July 2003, the Social Welfare Services Act was reformed to legislate the classification
# AI: The Brothers_Home article might be trending on Wikipedia on January 5, 2025, due to the recent revelations and discussions surrounding the dark history and human rights abuses that occurred at this South Korean internment camp during the 1970s and 1980s, sparking renewed public interest and scrutiny.
# Human: Act as a professional news summarizer. Based on your knowledge of Squid_Game and the following extract. In 1 concise and confident sentence, explain why the Squid_Game article might be trending on Wikipedia on #2025-01-05 10:56:07.753157:
#
# {{Short description|Netflix South Korean television series}}
# {{About|the Netflix television series|the Korean children's game|Squid (game)|the video game|Squids (video game){{!}}''Squids'' (video game)}}
# {{pp-vandalism|small=yes}}
# {{pp-move}}
# {{Use mdy dates|date=December 2024}}
# {{Infobox television
# | image                = Squid Game 2021 vector logo.svg
# | image_alt            = The official Korean logo of Squid Game
# | native_name          = {{Infobox Korean television name|hangul=오징어 게임|rr=Ojing-eo Geim|mr=Ojingŏ Keim}}
# | genre                = {{Plainlist|
# * [[Utopian and dystopian fiction|Dystopian]]
# * [[Survival film|Survival]]<ref name="genre">{{cite web |url=https://www.dw.com/en/what-distinguishes-squid-game-from-other-survival-thrillers/a-59422159 |title='Squid Game': more than a traditional survival thriller |last=Lehnen |first=Christine |date=October 6, 2021 |website=[[Deutsche Welle]] |access-date=November 1, 2024 |archive-date=June 21, 2024 |archive-url=https://web.archive.org/web/20240621022531/https://www.dw.com/en/what-distinguishes-squid-game-from-other-survival-thrillers/a-59422159 |url-status=live }}</ref>
# * [[Thriller (genre)#Television|Thriller]]<ref name="genre" />
# * [[Korean horror|Horror]]<ref>{{cite web|last=Tan|first=Monica|date=September 30, 2021|title=Squid Game: the smash-hit South Korean horror is a perfect fit for our dystopian mood|url=https://www.theguardian.com/tv-and-radio/2021/oct/01/squid-game-the-smash-hit-south-korean-horror-is-a-perfect-fit-for-our-dystopian-mood|access-date=October 27, 2021|website=[[The Guardian]]|archive-date=October 26, 2021|archive-url=https://web.archive.org/web/20211026040214/https://www.theguardian.com/tv-and-radio/2021/oct/01/squid-game-the-smash-hit-south-korean-horror-is-a-perfect-fit-for-our-dystopian-mood|url-status=live}}</ref>
# }}
# | creator              = [[Hwang Dong-hyuk]]
# | writer               = Hwang Dong-hyuk
# | director             = Hwang Dong-hyuk
# | starring             = {{Plainlist|
# * [[Lee Jung-jae]]
# * [[Wi Ha-joon]]
# * [[Lee Byung-hun]]
# }}
# | music                = [[Jung Jae-il]]
# | country              = South Korea
# | language             = Korean
# | num_seasons          = 2<!-- Increment when new seasons begin. -->
# | num_episodes         = 16 ([[#Episodes|List of episodes]])
# | list_episodes        =
# | executive_producer   = {{Plainlist|
# * Kim Ji-yeon<ref name="credits">{{cite episode |script-title=ko:무궁화 꽃이 피던 날 |trans-title=Red Light, Green Light |series=Squid Game |series-link=Squid Game season 1 |network=[[Netflix]] |date=September 17, 2021 |season=1 |number=1 |language=ko}}</ref>
# * Hwang Dong-hyuk<ref name="credits" />
# }}
# | producer             = {{Plainlist|
# * Han Heung-seok<ref name="credits" />
# * Kim Ji-eun (Season 2)<ref name="credits2">{{cite episode |script-title=ko:빵과 복권 |trans-title=Bread and Lottery |series-link=Squid Game season 2 |network=[[Netflix]] |date=December 26, 2024 |season=2 |number=1 |language=ko}}</ref>
# }}
# | cinematography       = {{Plainlist|
# * Lee Hyung-deok (Season 1)<ref name="credits" />
# * Kim Ji-yong (Season 2)<ref name="credits2" />
# }}
# | editor               = [[Nam Na-yeong]]<ref>{{cite web|title=Catching up with Emmy-nominated "Squid Game" Editor Nam Na-young|url=https://www.filmmakeru.com/blog/squid-game-editor-Nam-Na-Young|website=Filmmaker U|date=August 19, 2022|access-date=August 26, 2022|archive-date=August 26, 2022|archive-url=https://web.archive.org/web/20220826163238/https://www.filmmakeru.com/blog/squid-game-editor-Nam-Na-Young|url-status=live}}</ref>
# | camera               = [[Multi-camera]]
# | runtime              = 33–76 minutes
# | company              = Siren Pictures Inc.<ref>{{cite web|last=Lee|first=Julie|date=August 10, 2021|title=Squid Game invites you to deadly childhood games on September 17|url=https://about.netflix.com/en/news/squid-game-invites-you-to-deadly-childhood-games-on-september-17|url-status=live|archive-url=https://web.archive.org/web/20210811094811/https://about.netflix.com/en/news/squid-game-invites-you-to-deadly-childhood-games-on-september-17|archive-date=August 11, 2021|access-date=August 12, 2021|website=Netflix Media Center}}</ref>
# | budget               = {{Plainlist|
# * {{USD|21.4}}{{nbsp}}million (Season 1)
# * {{KRW|100}}{{nbsp}}billion (Season 2-3)<ref>{{Cite web |last=Ha |first=Soo-jung |date=January 6, 2024 |title= |script-title=ko: 주연 이정재 14억→조연 탑·이서환 3억..'오겜2' 출연료 진실 [Oh!쎈 이슈] |trans-title=Lead actor Lee Jung-jae 1.4 billion → Supporting actors Top and Lee Seo-hwan 300 million.. The truth about the appearance fee for 'Ogame 2' [Oh! Strong Issue] |url=https://m.entertain.naver.com/now/article/109/0005222392 |access-date=January 6, 2024 |website=Osen News |language=ko |via=Naver}}</ref>
# }}
# | network              = [[Netflix]]
# | first_aired          = {{Start date|2021|09|17}}
# | last_aired           = present <!-- {{End date|2025||}} -->
# | related              = ''[[Squid Game: The Challenge]]''
# }}
#
# '''''Squid Game''''' ({{Korean|오징어 게임}}; originally
# AI: The Squid_Game article might be trending on Wikipedia on January 5, 2025, possibly due to the release or announcement of new seasons or related projects, renewing interest and engagement in the popular South Korean dystopian thriller series.
# Human: Act as a professional news summarizer. Based on your knowledge of Luke_Littler and the following extract. In 1 concise and confident sentence, explain why the Luke_Littler article might be trending on Wikipedia on #2025-01-05 10:56:07.753157:
#
# {{Short description|English darts player (born 2007)}}
# {{Use British English|date=December 2024}}
# {{Use dmy dates|date=December 2024}}
# {{Infobox darts player
# | name = Luke Littler
# | image = Luke Littler (3x4 cropped).png
# | caption = Littler in May 2024
# | fullname =
# | nickname = The Nuke
# | birth_date = {{birth date and age|2007|1|21|df=y}}
# | birth_place =
# | hometown = [[Warrington]], England
# | since = 2017 <!--Do not add 2008, he did not play competitive darts at 18 months old -->
# | darts = 23g Target
# | laterality = Right-handed
# | music = "[[Greenlight (Pitbull song)|Greenlight]]" by [[Pitbull (rapper)|Pitbull]] featuring [[Flo Rida]] and [[LunchMoney Lewis]]
# | BDO = 2019–2020
# | PDC = 2023–<br/><small>(Tour Card: 2024–)</small>
# | WDF = 2019–2023
# | currentrank = {{PDC Rankings|Luke Littler}}
# | BDO World = Last 16: [[2022 WDF World Darts Championship|2022]]
# | World Masters = Last 64: [[2022 World Masters (darts)|2022]]
# | PDC World = '''Winner (1)''': [[2025 PDC World Darts Championship|2025]]
# | Matchplay = Last 32: [[2024 World Matchplay|2024]]
# | Grand Prix = Last 32: [[2024 World Grand Prix (darts)|2024]]
# | Grand Slam = '''Winner (1)''': [[2024 Grand Slam of Darts|2024]]
# | UK Open = Quarter Final: [[2024 UK Open|2024]]
# | European = Last 32: [[2024 European Championship (darts)|2024]]
# | Premier League = '''Winner (1)''': [[2024 Premier League Darts|2024]]
# | PC Finals = Runner Up: [[2024 Players Championship Finals|2024]]
# | Masters =
# | World Series Finals = '''Winner (1)''': [[2024 World Series of Darts Finals|2024]]
# | results = {{aligned table|leftright=y|fullwidth=y|class=nowrap
# | '''[[British Classic (darts)|British Classic]]''' | 2023
# | '''[[British Open (darts)|British Open]]''' | 2023
# | '''[[Irish Open (darts)|Irish Open]]''' | 2021
# | '''[[Isle of Man Open#Isle of Man Classic|Isle of Man Classic]]''' | 2023
# | '''[[Romanian Classic (darts)|Romanian Classic]]''' | 2022
# | '''[[Welsh Open (darts)|Welsh Open]]''' | 2022
# | '''MODUS Super Series 3''' | 2023
# | '''MODUS Super Series 4''' | 2023
# }}
# '''''European Tour Events'''''
# {{aligned table|leftright=y|fullwidth=y|class=nowrap
# | '''Austrian Darts Open'''| [[2024 Austrian Darts Open|2024]]
# | '''Belgian Darts Open'''| [[2024 Belgian Darts Open|2024]]
# }}
# '''''Players Championships'''''
# {{aligned table|leftright=y|fullwidth=y|class=nowrap
# | '''Players Championship ([[Milton Keynes|MK]])'''| [[2024 PDC Players Championship series|2024]]
# | '''Players Championship ([[Wigan|WIG]])'''| [[2024 PDC Players Championship series|2024]] (x2)
# }}
# '''''World Series of Darts'''''
# {{aligned table|leftright=y|fullwidth=y|class=nowrap| '''Bahrain Darts Masters'''| [[2024 Bahrain Darts Masters|2024]]
# |'''Poland Darts Masters'''| [[2024 Poland Darts Masters|2024]]
# }}
# '''''Youth events'''''
# {{aligned table|leftright=y|fullwidth=y|class=nowrap
# | '''[[British Classic (darts)|British Classic]]''' | 2021
# | '''[[England Open (darts)|England Open]]''' | 2021, 2022
# | '''[[Isle of Man Open]]''' | 2019, 2020,<br/>2022, 2023
# | '''[[Welsh Open (darts)|Welsh Open]]''' | 2021, 2022
# | '''JDC Tour''' | 2020 (x2)
# }}
# | medaltemplates =
# {{MedalSport | Men's [[Darts]]}}
# {{MedalCountry | {{ENG}}}}
# {{MedalCompetition | [[WDF Europe Cup]]}}
# {{MedalGold | [[2022 WDF Europe Cup|2022 Gandía]] | Men's team}}
# ...
# Human: Act as a professional news summarizer. Based on your knowledge of Luke_Littler and the following extract. In 1 concise and confident sentence, explain why the Luke_Littler article might be trending on Wikipedia on #2025-01-05 10:56:07.753157:
#
# {{Short description|English darts player (born 2007)}}
# {{pp-vandalism|small=yes}}
# {{Use British English|date=December 2024}}
# {{Use dmy dates|date=December 2024}}
# {{Infobox darts player
# | name = Luke Littler
# | image = Luke Littler (3x4 cropped).png
# | caption = Littler in May 2024
# | fullname =
# | nickname = The Nuke
# | birth_date = {{birth date and age|2007|1|21|df=y}}
# | birth_place =
# | hometown = [[Warrington]], England
# | since = 2017 <!--Do not add 2008, he did not play competitive darts at 18 months old -->
# | darts = 23g Target
# | laterality = Right-handed
# | music = "[[Greenlight (Pitbull song)|Greenlight]]" by [[Pitbull (rapper)|Pitbull]] featuring [[Flo Rida]] and [[LunchMoney Lewis]]
# | BDO = 2019–2020
# | PDC = 2023–<br/><small>(Tour Card: 2024–)</small>
# | WDF = 2019–2023
# | currentrank = {{PDC Rankings|Luke Littler}}
# | BDO World = Last 16: [[2022 WDF World Darts Championship|2022]]
# | World Masters = Last 64: [[2022 World Masters (darts)|2022]]
# | PDC World = '''Winner (1)''': [[2025 PDC World Darts Championship|2025]]
# | Matchplay = Last 32: [[2024 World Matchplay|2024]]
# | Grand Prix = Last 32: [[2024 World Grand Prix (darts)|2024]]
# | Grand Slam = '''Winner (1)''': [[2024 Grand Slam of Darts|2024]]
# | UK Open = Quarter Final: [[2024 UK Open|2024]]
# | European = Last 32: [[2024 European Championship (darts)|2024]]
# | Premier League = '''Winner (1)''': [[2024 Premier League Darts|2024]]
# | PC Finals = Runner Up: [[2024 Players Championship Finals|2024]]
# | Masters =
# | World Series Finals = '''Winner (1)''': [[2024 World Series of Darts Finals|2024]]
# | results = {{aligned table|leftright=y|fullwidth=y|class=nowrap
# | '''[[British Classic (darts)|British Classic]]''' | 2023
# | '''[[British Open (darts)|British Open]]''' | 2023
# | '''[[Irish Open (darts)|Irish Open]]''' | 2021
# | '''[[Isle of Man Open#Isle of Man Classic|Isle of Man Classic]]''' | 2023
# | '''[[Romanian Classic (darts)|Romanian Classic]]''' | 2022
# | '''[[Welsh Open (darts)|Welsh Open]]''' | 2022
# | '''MODUS Super Series 3''' | 2023
# | '''MODUS Super Series 4''' | 2023
# }}
# '''''European Tour Events'''''
# {{aligned table|leftright=y|fullwidth=y|class=nowrap
# | '''Austrian Darts Open'''| [[2024 Austrian Darts Open|2024]]
# | '''Belgian Darts Open'''| [[2024 Belgian Darts Open|2024]]
# }}
# '''''Players Championships'''''
# {{aligned table|leftright=y|fullwidth=y|class=nowrap
# | '''Players Championship ([[Milton Keynes|MK]])'''| [[2024 PDC Players Championship series|2024]]
# | '''Players Championship ([[Wigan|WIG]])'''| [[2024 PDC Players Championship series|2024]] (x2)
# }}
# '''''World Series of Darts'''''
# {{aligned table|leftright=y|fullwidth=y|class=nowrap| '''Bahrain Darts Masters'''| [[2024 Bahrain Darts Masters|2024]]
# |'''Poland Darts Masters'''| [[2024 Poland Darts Masters|2024]]
# }}
# '''''Youth events'''''
# {{aligned table|leftright=y|fullwidth=y|class=nowrap
# | '''[[British Classic (darts)|British Classic]]''' | 2021
# | '''[[England Open (darts)|England Open]]''' | 2021, 2022
# | '''[[Isle of Man Open]]''' | 2019, 2020,<br/>2022, 2023
# | '''[[Welsh Open (darts)|Welsh Open]]''' | 2021, 2022
# | '''JDC Tour''' | 2020 (x2)
# }}
# | medaltemplates =
# {{MedalSport | Men's [[Darts]]}}
# {{MedalCountry | {{ENG}}}}
# {{MedalCompetition | [[WDF Europe Cup]]}}
# {{MedalGold | [[2022 WDF Europe Cup|2022 Gandía]] | Men's team}}
# {{MedalGold | [[2022 WDF Europe Cup|2022 Gandía]] | Men's overall}}
# {{MedalCompetition | [[WDF Europe Youth Cup|WDF Europe Cup Youth]]}}
# {{MedalGold | [[2022 WDF Europe Cup Youth|2022 Budapest]] | Boys singles}}
# {{MedalGold | [[2022 WDF Europe Cup Youth|2022 Budapest]] | Boys team}}
# {{MedalGold | [[2022 WDF Europe Cup Youth|2022 Budapest]] | Boys overall}}
# {{MedalBronze | [[2022 WDF Europe Cup Youth|2022 Budapest]] | Boys pairs}}
# }}
# '''Luke Littler''' (born 21 January 2007) is an English professional [[darts]] player who competes in [[Professional Darts Corporation]] (PDC) events, where he is currently ranked [[PDC Order of Merit|world number two]]. He is the reigning [[PDC World Darts Championship|PDC World Champion]] after winning the [[2025 PDC World Darts Championship|2025 World Championship]], defeating [[Michael van Gerwen]] in the final, where he became the youngest world champion in darts history, at 17 years and 347 days old. Littler has won 11 senior PDC titles and is the reigning [[2024 Premier League Darts|Premier League]], [[2024 Grand Slam of Darts|Grand Slam]] and [[2024 World Series of Darts Finals|World Series Finals]] champion. He has also won two [[World Series of Darts]] titles and the [[2023 PDC World Youth Championship]].
#
# He was the runner-up at the premier events [[2024 PDC World Darts Championship|PDC World Championship]] and [[2024 Players Championship Finals|Players Championship Finals]] in 2024, losing to [[Luke Humphries]] in the final on both occasions.
#
# In his youth career, Littler also won five [[2023 PDC Development Tour series|PDC Development Tours]], the [[2022 World Masters (darts)#Boys|2022 World Youth Masters]], and both the [[JDC World Dar
# AI: The Luke_Littler article might be trending on Wikipedia on January 5, 2025, following his historic victory as the youngest world champion in darts history at the 2025 PDC World Darts Championship, where he defeated Michael van Gerwen at just 17 years old.
# Human: Act as a professional news summarizer. Based on your knowledge of Pan_Am_Flight_103 and the following extract. In 1 concise and confident sentence, explain why the Pan_Am_Flight_103 article might be trending on Wikipedia on #2025-01-05 10:56:07.753157:
#
# {{Short description|Flight bombed by a terrorist over Scotland in 1988}}
# {{Redirect|Flight 103|other uses|Flight 103 (disambiguation)}}
# {{Use dmy dates|date=June 2024}}
# {{Use American English|date=June 2024}}
# {{Infobox aircraft occurrence
# | occurrence_type = Bombing
# | name            = Pan Am Flight 103
# | image           = Pan Am Flight 103. Crashed Lockerbie, Scotland, 21 December 1988.jpg
# | image_upright   = 1.15
# | alt             =
# | caption         = The remains of the forward section from ''Clipper Maid of the Seas'' on Tundergarth Hill
# | date            = {{start date|1988|12|21|df=y}}
# | summary         =
# | site            = [[Lockerbie]], Scotland
# | coordinates     = {{coord|55|06|56|N|003|21|31|W|type:event_globe:earth_region:GB-SCT|display=inline,title}}
# | plane1_image    = Pan American World Airways - Pan Am Boeing 747-121 N739PA "Clipper Maid of the Seas" (25017912834).jpg
# | plane1_image_upright = 1.15
# | plane1_caption  = N739PA, the aircraft involved as ''Clipper Maid of the Seas'' at [[Frankfurt Airport]] in 1986
# | total_fatalities = 270
# | origin          = [[Frankfurt Airport]], [[Frankfurt]], West Germany
# | stopover0       = [[Heathrow Airport]], London, United Kingdom
# | stopover1       = [[John F. Kennedy International Airport]], New York City, United States
# | destination     = [[Detroit Metropolitan Airport]], Michigan, United States
# | aircraft_type   = [[Boeing 747-100|Boeing 747-121]]
# | aircraft_name   = ''Clipper Maid of the Seas''
# | Operator        = [[Pan American World Airways]]
# | IATA            = PA103
# | ICAO            = PAA103
# | callsign        = CLIPPER 103
# | tail_number     = N739PA
# | occupants       = 259
# | passengers      = 243
# | crew            = 16
# | fatalities      = 259<!-- don't need to add "(all)", we already have survivors=0 -->
# | survivors       = 0
# | ground_fatalities = 11
# }}
#
# '''Pan Am Flight 103''' ('''PA103/PAA103''') was a regularly scheduled [[Pan Am]] [[transatlantic flight]] from [[Frankfurt]] to [[Detroit]] via a stopover in London and another in New York City. Shortly after 19:00 on 21 December 1988, while the [[Boeing 747]] "Clipper Maid of the Seas" was in flight over the Scottish town of [[Lockerbie]], it was destroyed by a bomb, killing all 243 passengers and 16 crew in what became known as the '''Lockerbie bombing'''.<ref name="panamair_victims">{{cite web |year=2007 |url=http://www.panamair.org/accidents/lockerbievictims.htm |title=Clipper Maid of the Seas: Remembering those on flight 103 |publisher=panamair.org |access-date=8 June 2008 |url-status=dead |archive-url=https://web.archive.org/web/20080326232104/http://www.panamair.org/accidents/lockerbievictims.htm |archive-date=26 March 2008 }}</ref> Large sections of the aircraft crashed in a residential street in Lockerbie, killing 11 residents. With a total of 270 fatalities, it is the deadliest [[Terrorism in the United Kingdom|terrorist attack in the history of the United Kingdom]].
#
# Following a three-year joint investigation by [[Dumfries and Galloway Constabulary]] and the US [[Federal Bureau of Investigation]] (FBI), arrest warrants were issued for two Libyan nationals in November 1991. After protracted negotiations and United Nations sanctions, in 1999, [[History of Libya under Muammar Gaddafi|Libyan]] leader [[Muammar Gaddafi]] handed over the two men for trial at [[Scottish Court in the Netherlands|Camp Zeist, the Netherlands]]. In 2001, [[Abdelbaset al-Megrahi]], a Libyan intelligence officer, was jailed for life after being found guilty of 270 counts of murder in connection with the bombing. In August 2009, he was [[Release of Abdelbaset al-Megrahi|released]] by the [[Scottish Government]] on [[Compassionate release|compassionate grounds]] after being diagnosed with [[prostate cancer]]. He died in May 2012 as the only person to be convicted for the attack.
#
# In 2003, Gaddafi accepted Libya's responsibility for the Lockerbie bombing, and paid over a billion dollars in compensation to the families of the victims, a very unusual outcome for a terrorist bombing. Although Gaddafi  maintained that he had never personally given the order for the attack,<ref name=BBC/> acceptance of Megrahi's status as a government employee was used to connect responsibility by Libya with a series of requirements laid out by a UN resolution for sanctions against Libya to be lifted.<ref>{{Cite web |date=13 August 2003 |title=Libya ready to accept responsibility for Lockerbie bombing |url=http://www.independent.co.uk/news/world/africa/libya-ready-to-accept-responsibility-for-lockerbie-bombing-100088.html |archive-url=https://ghostarchive.org/archive/20220524/http://www.independent.co.uk/news/world/africa/libya-ready-to-accept-responsibility-for-lockerbie-bombing-100088.html |archive-date=24 May 2022 |url-access=subscription |url-status=live |access-date=13 June 2020 |website=The Independent}}</ref> In 2011, during the [[Libyan Civil War (2011)|First Libyan Civil War]], former Minister of Justice [[Mustafa Abdul Jalil]
# AI: The Pan_Am_Flight_103 article might be trending on Wikipedia on January 5, 2025, due to ongoing discussions and renewed interest in the Lockerbie bombing case as the anniversary of the tragic event approaches, which killed 270 people and remains a significant topic in discussions about aviation security and terrorism.
# Human: Does Jeff_Baena relate to any other trending article? If yes, tell me why in 1 or 2 sentences.
# AI: Yes, Jeff Baena relates to the trending article about Aubrey Plaza, as he was her husband until his recent death on January 3, 2025. This connection has led to increased public interest in both their personal lives and professional careers, particularly in the wake of his passing.
# Human: Does Aubrey_Plaza relate to any other trending article? If yes, tell me why in 1 or 2 sentences.
# AI: Yes, Aubrey Plaza relates to the trending article about Jeff Baena, as she was his wife until his death on January 3, 2025. The news of Baena's passing has heightened public interest in Plaza, prompting discussions about her career and personal life during this difficult time.
# Human: Does Squid_Game_season_2 relate to any other trending article? If yes, tell me why in 1 or 2 sentences.
# AI: Yes, Squid_Game_season_2 relates to the trending article about Squid_Game, as the release of the second season on December 26, 2024, has generated renewed interest in the overall series. This connection has sparked discussions about the show's themes, characters, and impact on popular culture, further driving traffic to both articles.
# Human: Does Human_metapneumovirus relate to any other trending article? If yes, tell me why in 1 or 2 sentences.
# AI: Yes, Human_metapneumovirus relates to the trending articles about recent outbreaks of respiratory viruses, as the current outbreak of HMPV in China has raised public health concerns and discussions regarding viral infections. This situation has increased interest in understanding the virus's implications, symptoms, and transmission, linking it to broader discussions about respiratory illnesses.
# Human: Does Nosferatu_(2024_film) relate to any other trending article? If yes, tell me why in 1 or 2 sentences.
# AI: Yes, Nosferatu_(2024_film) relates to the broader trending discussions around horror films and remakes, particularly due to its release during the holiday season and its connection to the iconic 1922 silent film. The film's reception, box office success, and the involvement of renowned director Robert Eggers have sparked renewed interest in classic horror adaptations, making it a relevant topic in film discussions.
# Human: Does Jimmy_Carter relate to any other trending article? If yes, tell me why in 1 or 2 sentences.
# AI: Yes, Jimmy_Carter relates to the trending article about the recent passing of Jeff Baena, as both articles are receiving attention due to significant events in the lives of notable figures. Carter's death on December 29, 2024, at the age of 100, has prompted widespread reflection on his legacy and contributions, which parallels the public interest surrounding Baena's career and his relationship with actress Aubrey Plaza.
# Human: Does Brothers_Home relate to any other trending article? If yes, tell me why in 1 or 2 sentences.
# AI: Yes, Brothers_Home relates to trending discussions about human rights abuses and historical injustices in South Korea, particularly in light of ongoing conversations about government accountability and social justice. Recent revelations and legal actions regarding the treatment of individuals at the facility have rekindled public interest in the camp's dark history, prompting a broader examination of state-sponsored oppression during that era.
# Human: Does Squid_Game relate to any other trending article? If yes, tell me why in 1 or 2 sentences.
# AI: Yes, Squid_Game relates to the trending article about Squid_Game_season_2, as the recent release of the second season has reignited discussions about the series' themes, characters, and cultural impact. The buzz surrounding the new season has led to increased interest in the original show, making both articles relevant in the context of current entertainment news.
# Human: Does Luke_Littler relate to any other trending article? If yes, tell me why in 1 or 2 sentences.
# AI: Yes, Luke_Littler relates to the trending articles about the PDC World Darts Championship, particularly because he recently won the 2025 championship, making headlines as the youngest world champion in darts history. This significant achievement has drawn attention to his career and the sport of darts, connecting him to broader discussions about young talent in competitive sports.
# Human: Does Pan_Am_Flight_103 relate to any other trending article? If yes, tell me why in 1 or 2 sentences.
#
# > Finished chain.
# memorycontext: Yes, Pan_Am_Flight_103 relates to the discussions surrounding terrorism and aviation security, particularly as the anniversary of the Lockerbie bombing approaches, which occurred on December 21, 1988. This commemoration often prompts renewed interest in the historical implications of the attack, the subsequent investigations, and ongoing conversations about security measures in air travel.

# %%
# # First interaction
# response = conversation.predict(input="Hello! What's your name?")
# print("AI:", response)

# # Second interaction
# response = conversation.predict(input="What was my first question to you?")
# print("AI:", response)

# Save the conversation memory
# save_memory(conversation.memory)

# %%
# Continue the conversation
response = new_conversation.predict(input="Which model are you using?")
print("AI:", response)

# %% [markdown]
# #### Build HTML Page to display the top 10 list complete with
# - title
# - thumbnail
# - trending reason
# - relation to other articles

# %%
# Start building the HTML
html_title = f"<h1>Wikipedia's most viewed articles on {date_to_query.strftime("%B %d, %Y")}</h1>"
html_list = "<ol>\n"

# Iterate through the data
for item in article_list:
    title = item['title']
    link = item['link']
    thumbnail = item['thumbnail']
    trendingreason = item['trendingreason']
    
    memorycontext = item['memorycontext']
    views = item['views']
    extract = item['extract']

    # Handle null thumbnail
    if thumbnail:
        thumbnail_html = f'<img src="{thumbnail}" alt="Thumbnail for {title}"/><br>'
    else:
        thumbnail_html = '<p><em>No thumbnail available</em></p>'
    
    # Create a list item for each entry
    html_list += f"""
    <li>
        <h2>
          <a href="{link}" target="_blank">{title}</a><br>
        </h2>
        {thumbnail_html}
        <strong>Views:</strong> {views}<br><br>
        <strong>Reason for Trending:</strong> {trendingreason}<br><br>
        <strong>Relation to knowledge base:</strong> {memorycontext}
        
    </li>\n
    """

# Close the HTML list
html_list += "</ol>"

html_page = html_title + html_list
# Save to html file (overwrite if it already exists)
file_path = f'{file_directory}/{base_file_name}.html'

with open(file_path, 'w', encoding='utf-8') as file:
    file.write(html_page)

# Display the HTML in the notebook
from IPython.display import display, HTML
display(HTML(html_page))
# Out:
# <h1>Wikipedia's most viewed articles on January 05, 2025</h1><ol>
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Jeff_Baena" target="_blank">Jeff_Baena</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/d/dc/Jeff_Baena.jpg/320px-Jeff_Baena.jpg" alt="Thumbnail for Jeff_Baena"/><br>
#         <strong>Views:</strong> 716965<br><br>
#         <strong>Reason for Trending:</strong> The Jeff_Baena article might be trending on Wikipedia on January 5, 2025, due to the recent news of his death on January 3, 2025, at the age of 47, which has brought attention to his career and contributions to film as a screenwriter and director.<br><br>
#         <strong>Relation to knowledge base:</strong> Yes, Jeff Baena relates to the trending article about Aubrey Plaza, as he was her husband until his recent death on January 3, 2025. This connection has led to increased public interest in both their personal lives and professional careers, particularly in the wake of his passing.
#
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Aubrey_Plaza" target="_blank">Aubrey_Plaza</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/29/Aubrey_Plaza_at_the_2024_Cannes_Film_Festival_%28cropped%29.jpg/320px-Aubrey_Plaza_at_the_2024_Cannes_Film_Festival_%28cropped%29.jpg" alt="Thumbnail for Aubrey_Plaza"/><br>
#         <strong>Views:</strong> 605176<br><br>
#         <strong>Reason for Trending:</strong> The Aubrey_Plaza article might be trending on Wikipedia on January 5, 2025, following the recent passing of her husband, Jeff Baena, on January 3, 2025, which has drawn public attention to her personal and professional life.<br><br>
#         <strong>Relation to knowledge base:</strong> Yes, Aubrey Plaza relates to the trending article about Jeff Baena, as she was his wife until his death on January 3, 2025. The news of Baena's passing has heightened public interest in Plaza, prompting discussions about her career and personal life during this difficult time.
#
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Squid_Game_season_2" target="_blank">Squid_Game_season_2</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/en/3/38/Squid_Game_season_2_poster.png" alt="Thumbnail for Squid_Game_season_2"/><br>
#         <strong>Views:</strong> 306354<br><br>
#         <strong>Reason for Trending:</strong> The Squid_Game_season_2 article might be trending on Wikipedia on January 5, 2025, following the recent release of its second season on December 26, 2024, which has generated significant buzz and critical acclaim among fans and viewers of the series.<br><br>
#         <strong>Relation to knowledge base:</strong> Yes, Squid_Game_season_2 relates to the trending article about Squid_Game, as the release of the second season on December 26, 2024, has generated renewed interest in the overall series. This connection has sparked discussions about the show's themes, characters, and impact on popular culture, further driving traffic to both articles.
#
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Human_metapneumovirus" target="_blank">Human_metapneumovirus</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/e1/Pathogens-04-00682-g001.png/320px-Pathogens-04-00682-g001.png" alt="Thumbnail for Human_metapneumovirus"/><br>
#         <strong>Views:</strong> 239524<br><br>
#         <strong>Reason for Trending:</strong> The Human_metapneumovirus article might be trending on Wikipedia on January 5, 2025, due to a current outbreak of HMPV in China, which has raised awareness and concern about the virus and its impact on public health globally.<br><br>
#         <strong>Relation to knowledge base:</strong> Yes, Human_metapneumovirus relates to the trending articles about recent outbreaks of respiratory viruses, as the current outbreak of HMPV in China has raised public health concerns and discussions regarding viral infections. This situation has increased interest in understanding the virus's implications, symptoms, and transmission, linking it to broader discussions about respiratory illnesses.
#
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Nosferatu_(2024_film)" target="_blank">Nosferatu_(2024_film)</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/en/4/48/Nosferatu_IMAX_poster_2024.jpg" alt="Thumbnail for Nosferatu_(2024_film)"/><br>
#         <strong>Views:</strong> 237201<br><br>
#         <strong>Reason for Trending:</strong> The Nosferatu_(2024_film) article might be trending on Wikipedia on January 5, 2025, due to the film's recent release in the United States on December 25, 2024, and its impressive box office success, grossing over $100 million while receiving generally positive reviews from critics.<br><br>
#         <strong>Relation to knowledge base:</strong> Yes, Nosferatu_(2024_film) relates to the broader trending discussions around horror films and remakes, particularly due to its release during the holiday season and its connection to the iconic 1922 silent film. The film's reception, box office success, and the involvement of renowned director Robert Eggers have sparked renewed interest in classic horror adaptations, making it a relevant topic in film discussions.
#
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Jimmy_Carter" target="_blank">Jimmy_Carter</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/ea/JimmyCarterPortrait_%28cropped%29.jpg/320px-JimmyCarterPortrait_%28cropped%29.jpg" alt="Thumbnail for Jimmy_Carter"/><br>
#         <strong>Views:</strong> 232811<br><br>
#         <strong>Reason for Trending:</strong> The Jimmy_Carter article might be trending on Wikipedia on January 5, 2025, following the recent death of the former president on December 29, 2024, at the age of 100, which has prompted widespread reflection on his legacy and contributions to American history.<br><br>
#         <strong>Relation to knowledge base:</strong> Yes, Jimmy_Carter relates to the trending article about the recent passing of Jeff Baena, as both articles are receiving attention due to significant events in the lives of notable figures. Carter's death on December 29, 2024, at the age of 100, has prompted widespread reflection on his legacy and contributions, which parallels the public interest surrounding Baena's career and his relationship with actress Aubrey Plaza.
#
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Brothers_Home" target="_blank">Brothers_Home</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/en/thumb/8/8f/BrothersHomeBusan.jpeg/320px-BrothersHomeBusan.jpeg" alt="Thumbnail for Brothers_Home"/><br>
#         <strong>Views:</strong> 196141<br><br>
#         <strong>Reason for Trending:</strong> The Brothers_Home article might be trending on Wikipedia on January 5, 2025, due to renewed discussions and public interest surrounding the facility's notorious history of human rights abuses in South Korea during the 1970s and 1980s, particularly as new revelations and legal actions continue to emerge regarding its impact on victims and society.<br><br>
#         <strong>Relation to knowledge base:</strong> Yes, Brothers_Home relates to trending discussions about human rights abuses and historical injustices in South Korea, particularly in light of ongoing conversations about government accountability and social justice. Recent revelations and legal actions regarding the treatment of individuals at the facility have rekindled public interest in the camp's dark history, prompting a broader examination of state-sponsored oppression during that era.
#
#     </li>
#
#
#     <li>

# %% [markdown]
# ## Takeaways
# - running two separate chains revealed some copy-pasta growing pains
# - LangChain defaults to GPT-3 when no model is specified
# - GPT 4o mini is a token-lover's dream
# - It's tough to get the model to calm down when asking questions of it's knowledgebase.
