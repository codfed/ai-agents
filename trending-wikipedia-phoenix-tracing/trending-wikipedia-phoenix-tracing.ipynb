# %% [markdown]
# # Trending Wikipedia
#
# 1. Get trending Wikipedia articles from yesterday
# 2. Pass plain text from article to OpenAI for suggestsions as to why each article is trending
# 3. Build HTML page to display each article and why it is trending
#
# #### But this time with phoenix to trace it and iterate!

# %%
# !pip install requests python-dotenv openai arize-phoenix openinference-instrumentation-openai

# %%
from dotenv import load_dotenv
import os

load_dotenv()

OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]

# %% [markdown]
# # The Phoenix part
#
# 1. Launch Phoenix
# 2. Register Phoenix as the trace provider
# 3. Initialize the OpenAI Instrumentor with the Phoenix trace provider
#
# After all these are finished, all of our calls to ChatGPT will be recorded

# %% [markdown]
# #### Launch Phoenix
# This will lauch phoenix locally. We will connect to this later on in the notebook.
#
# Note: This cell will give benign errors if you run it twice.

# %%
import phoenix as px
px.launch_app()
# Out:
# 🌍 To view the Phoenix app in your browser, visit http://localhost:6006/
# 📖 For more information on how to use Phoenix, check out https://docs.arize.com/phoenix

# %% [markdown]
# #### Connect OpenAI Instrumentor to Phoenix

# %%
from phoenix.otel import register
from openinference.instrumentation.openai import OpenAIInstrumentor

tracer_provider = register(
  project_name="trending-wikipedia-phoenix-tracing", # Default is 'default'
)

OpenAIInstrumentor().instrument(tracer_provider=tracer_provider)
# Out:
# 🔭 OpenTelemetry Tracing Details 🔭
# |  Phoenix Project: trending-wikipedia-phoenix-tracing
# |  Span Processor: SimpleSpanProcessor
# |  Collector Endpoint: localhost:4317
# |  Transport: gRPC
# |  Transport Headers: {'user-agent': '****'}
# |
# |  Using a default SpanProcessor. `add_span_processor` will overwrite this default.
# |
# |  `register` has set this TracerProvider as the global OpenTelemetry default.
# |  To disable this behavior, call `register` with `set_global_tracer_provider=False`.

# %% [markdown]
# ### Now each time we use OpenAI, it will be logged in our Phoenix application

# %% [markdown]
# API call for the featured feed shows different for today than it does for any previous days.
#
# This is written for previous days only

# %%
import requests
import datetime

today = datetime.datetime.now()
yesterday = today - datetime.timedelta(days=1)

date_to_query = yesterday
url = 'https://api.wikimedia.org/feed/v1/wikipedia/en/featured/' + date_to_query.strftime('%Y/%m/%d')


response = requests.get(url)
featured_feed = response.json()
print(f"API call: {url}")
print(f"Retrieved Wikipedia top article statistics for {date_to_query}")
# Out:
# API call: https://api.wikimedia.org/feed/v1/wikipedia/en/featured/2025/01/04
# Retrieved Wikipedia top article statistics for 2025-01-04 11:38:18.018141

# %% [markdown]
# ### Save API response to file

# %%
import os
import json

# Ensure the 'featured-feed' folder exists
file_directory = "data"
os.makedirs(file_directory, exist_ok=True)

# Define the filename based on the date
base_file_name = date_to_query.strftime('%Y-%m-%d')
file_path = f'{file_directory}/{base_file_name}.json'

# Save to JSON file (overwrite if it already exists)
with open(file_path, 'w', encoding='utf-8') as file:
    json.dump(featured_feed, file, indent=4, ensure_ascii=False)

print(f'Saved Wikipedia response to {file_path}')
# Out:
# Saved Wikipedia response to data/2025-01-04.json

# %% [markdown]
# ### Make `article_list` with only relevant information

# %%
article_list = []

for item in featured_feed['mostread']['articles'][:20]:
    title = item['title']
    views = item['views']
    link = item['content_urls']['desktop']['page']
    extract = item['extract']
    thumbnail = item.get('thumbnail', {}).get('source', None)

    print(f"Getting full text of {title} article")


    # Download raw text of article
    url = f"https://en.wikipedia.org/w/index.php?title={title}&action=raw"
    print(url)

    article_text = requests.get(url).text
    article_text_truncated = article_text[:5000]

    
    
    article={
        'title': title,
        'views': views,
        'link': link,
        'thumbnail': thumbnail,
        'extract': extract,
        'text': article_text_truncated,
        'trendingreason': ''
    }

    article_list.append(article)

print(article_list)
# Out:
# Getting full text of Squid_Game_season_2 article
# https://en.wikipedia.org/w/index.php?title=Squid_Game_season_2&action=raw
# Getting full text of Luke_Littler article
# https://en.wikipedia.org/w/index.php?title=Luke_Littler&action=raw
# Getting full text of Marcus_Freeman article
# https://en.wikipedia.org/w/index.php?title=Marcus_Freeman&action=raw
# Getting full text of Nosferatu_(2024_film) article
# https://en.wikipedia.org/w/index.php?title=Nosferatu_(2024_film)&action=raw
# Getting full text of Squid_Game article
# https://en.wikipedia.org/w/index.php?title=Squid_Game&action=raw
# Getting full text of Human_metapneumovirus article
# https://en.wikipedia.org/w/index.php?title=Human_metapneumovirus&action=raw
# Getting full text of Pushpa_2:_The_Rule article
# https://en.wikipedia.org/w/index.php?title=Pushpa_2:_The_Rule&action=raw
# Getting full text of Wayne_Osmond article
# https://en.wikipedia.org/w/index.php?title=Wayne_Osmond&action=raw
# Getting full text of Avicii article
# https://en.wikipedia.org/w/index.php?title=Avicii&action=raw
# Getting full text of PDC_World_Darts_Championship article
# https://en.wikipedia.org/w/index.php?title=PDC_World_Darts_Championship&action=raw
# Getting full text of 2025_PDC_World_Darts_Championship article
# https://en.wikipedia.org/w/index.php?title=2025_PDC_World_Darts_Championship&action=raw
# Getting full text of 2025_New_Orleans_truck_attack article
# https://en.wikipedia.org/w/index.php?title=2025_New_Orleans_truck_attack&action=raw
# Getting full text of Michael_van_Gerwen article
# https://en.wikipedia.org/w/index.php?title=Michael_van_Gerwen&action=raw
# Getting full text of Pan_Am_Flight_103 article
# https://en.wikipedia.org/w/index.php?title=Pan_Am_Flight_103&action=raw
# Getting full text of Deaths_in_2025 article
# https://en.wikipedia.org/w/index.php?title=Deaths_in_2025&action=raw
# Getting full text of Mufasa:_The_Lion_King article
# https://en.wikipedia.org/w/index.php?title=Mufasa:_The_Lion_King&action=raw
# Getting full text of Norovirus article
# https://en.wikipedia.org/w/index.php?title=Norovirus&action=raw
# Getting full text of Wicked_(2024_film) article
# https://en.wikipedia.org/w/index.php?title=Wicked_(2024_film)&action=raw
# Getting full text of Marco_(2024_film) article
# https://en.wikipedia.org/w/index.php?title=Marco_(2024_film)&action=raw
# Getting full text of List_of_highest-grossing_Indian_films article
# https://en.wikipedia.org/w/index.php?title=List_of_highest-grossing_Indian_films&action=raw
# [{'title': 'Squid_Game_season_2', 'views': 336056, 'link': 'https://en.wikipedia.org/wiki/Squid_Game_season_2', 'thumbnail': 'https://upload.wikimedia.org/wikipedia/en/3/38/Squid_Game_season_2_poster.png', 'extract': 'The second season of the South Korean dystopian survival thriller television series Squid Game, marketed as Squid Game 2, is created by Korean television producer and writer Hwang Dong-hyuk. It was released on Netflix on December 26, 2024.', 'text': '{{Short description|Season of television series}}\n{{Infobox television season\n| season_number        = 2\n| bgcolour             = #FF9F80\n| image                = Squid Game season 2 poster.png\n| image_upright        = 1\n| image_alt            = Korean promotional poster featuring notable characters running away in a carousel-themed location with dead people on the ground\n| caption              = Promotional poster\n| showrunner           = [[Hwang Dong-hyuk]]\n| starring             = {{Plainlist|\n* [[Lee Jung-jae]]\n* [[Lee Byung-hun]]\n* [[Wi Ha-joon]]\n* [[Im Si-wan]] \n* [[Kang Ha-neul]] \n* [[Lee Jin-wook]]\n* [[Park Sung-hoon]] \n* [[Yang Dong-geun]] \n* [[Jo Yu-ri]] \n* [[Kang Ae-shim]]\n* {{Ill|Lee Seo-hwan|ko|이서환}}\n* [[Park Gyu-young]]\n}}\n| network              = [[Netflix]]\n| num_episodes         = 7\n| released             = {{Start date|2024|12|26}}\n| next_season          = \n}}\n\nThe second season of the South Korean [[Utopian and dystopian fiction|dystopian]] survival [[Thriller (genre)#Television|thriller]] television series \'\'[[Squid Game]]\'\', marketed as \'\'\'\'\'Squid Game 2\'\'\'\'\', is created by Korean television producer and writer [[Hwang Dong-hyuk]]. It was released on [[Netflix]] on December 26, 2024.\n\nThe season stars [[Lee Jung-jae]], [[Lee Byung-hun]], [[Wi Ha-joon]], [[Im Si-wan]], [[Kang Ha-neul]], [[Lee Jin-wook]], [[Park Sung-hoon]], [[Yang Dong-geun]], [[Jo Yu-ri]], [[Kang Ae-shim]], {{Ill|Lee Seo-hwan|ko|이서환}}, and [[Park Gyu-young]]. Set three years after the first season, the story focuses on [[Seong Gi-hun]]\'s life after winning the Squid Game, stop on going to the United States and returning to the games with a new resolution in mind. He once again dives into the mysterious survival game, starting another life-or-death game with new participants gathered to win the prize of {{KRW|45.6|link=yes}}{{nbsp}}billion ({{USD|31.1|link=yes}}{{nbsp}}million). A side-plot of the season sees [[Hwang Jun-ho (character)|Hwang Jun-ho]] trying to locate Gi-hun with help from hired mercenaries. \n\nThe season garnered positive reviews from critics. The [[Squid Game season 3|third and final season]] is confirmed to be released in 2025, which was filmed back-to-back with the second season.\n\n== Episodes ==\n<onlyinclude>{{Episode table |background=#FF9F80 |overall=5 |season=5 |title=43 |director=14 |writer=17 |airdate=16 |released=y |airdateR=<ref name="Season2Release">{{Cite web |last=Porter |first=Rick |date=July 31, 2024 |title=\'Squid Game\' to End With Season 3, Post-Christmas Return Set at Netflix |url=https://www.hollywoodreporter.com/tv/tv-news/squid-game-season-2-premiere-ending-season-3-1235963660/ |url-status=live |archive-url=https://web.archive.org/web/20241128194715/https://www.hollywoodreporter.com/tv/tv-news/squid-game-season-2-premiere-ending-season-3-1235963660/ |archive-date=November 28, 2024 |access-date=July 31, 2024 |website=[[The Hollywood Reporter]]}}</ref> |episodes={{Episode list/sublist|Squid Game season 2\n| EpisodeNumber   = 10\n| EpisodeNumber2  = 1\n| Title           = Bread and Lottery\n| NativeTitle     = 빵과 복권\n| TranslitTitle   = Ppang-gwa Bokgwon\n|NativeTitleLangCode = ko\n| DirectedBy      = [[Hwang Dong-hyuk]]\n| WrittenBy       = Hwang Dong-hyuk\n| OriginalAirDate = {{Start date|2024|12|26}}\n| ShortSummary    = Seong Gi-hun leaves the terminal{{Efn|As depicted in the [[Squid Game season 1|first season]] episode "One Lucky Day".}} determined to confront the Front Man behind the games. ...

# %% [markdown]
# ### Run through article list, prompt ChatGPT to decifer reasons for trending based on the infomration provided.

# %%
from openai import OpenAI
client = OpenAI(api_key=OPENAI_API_KEY)

for article in article_list:
    print(f"Analyzing {title}")

    title = article['title']
    text = article['text']

    prompt = f"Act as a professional news summarizer. Based on your knowledge of {title} and the following extract. In 1 concise and confident sentence, explain why the {title} article might be trending on Wikipedia on #{date_to_query}:\n\n{text}"

    response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "user",
        "content": prompt
        }
    ],
    temperature=1,
    max_tokens=512,
    top_p=1
    )
    print(f"trendingreason: {response.choices[0].message.content}")
    
    article['trendingreason'] =  response.choices[0].message.content
# Out:
# Analyzing List_of_highest-grossing_Indian_films
# trendingreason: The article on Squid Game Season 2 is likely trending on Wikipedia due to its recent release on December 26, 2024, generating significant viewer interest and discussion about its continuation shortly before the anticipated third and final season.
# Analyzing Squid_Game_season_2
# trendingreason: Luke Littler is trending on Wikipedia due to his historic achievement as the youngest PDC World Darts Champion, winning the title at just 17 years and 347 days old.
# Analyzing Luke_Littler
# trendingreason: The article about Marcus Freeman might be trending on Wikipedia on January 4, 2025, due to his recognition as the Bobby Dodd Coach of the Year in 2024, signaling his prominent impact and achievements as the head coach of the Notre Dame Fighting Irish football team.
# Analyzing Marcus_Freeman
# trendingreason: The article about the Nosferatu (2024 film) is trending on Wikipedia due to its recent theatrical release, critical acclaim, and impressive box office success, grossing over $100 million shortly after its premiere.
# Analyzing Nosferatu_(2024_film)
# trendingreason: The article about "Squid Game" is trending on Wikipedia likely due to the recent release of its highly anticipated second season on December 26, 2024, which has reignited global interest in the series.
# Analyzing Squid_Game
# trendingreason: The Human Metapneumovirus article is trending on Wikipedia due to a notable outbreak reported in China at the end of 2024, prompting increased public interest and concern over its impact on respiratory illness, particularly in vulnerable populations.
# Analyzing Human_metapneumovirus
# trendingreason: The article on "Pushpa 2: The Rule" is likely trending on Wikipedia on January 4, 2025, due to its recent theatrical release on December 5, 2024, and its impressive box office performance, grossing over ₹1,700 crore globally, capturing significant public and media interest.
# Analyzing Pushpa_2:_The_Rule
# trendingreason: The Wayne Osmond article is trending on Wikipedia following his recent death on January 1, 2025, which has sparked widespread public interest and tributes to his contributions as a musician with The Osmonds.
# Analyzing Wayne_Osmond
# trendingreason: The Avicii article might be trending on Wikipedia on January 4, 2025, due to renewed interest following a significant anniversary of his passing or the release of new posthumous material that has reignited public and media discussions about his impact on music and EDM culture.
# Analyzing Avicii
# trendingreason: The PDC World Darts Championship article is likely trending on Wikipedia following the conclusion of the 2025 tournament, where Luke Littler emerged as the champion, drawing significant attention and interest in the sport.
# Analyzing PDC_World_Darts_Championship
# trendingreason: The 2025 PDC World Darts Championship article is trending on Wikipedia because it features the historic victory of 17-year-old Luke Littler, who became the youngest world champion in darts history, capturing significant attention during and after the tournament's conclusion.
# Analyzing 2025_PDC_World_Darts_Championship
# trendingreason: The 2025 New Orleans truck attack article is trending on Wikipedia due to its tragic occurrence during New Year's celebrations resulting in multiple fatalities and injuries, highlighting ongoing concerns around domestic terrorism and the influence of extremist ideologies.
# Analyzing 2025_New_Orleans_truck_attack
# trendingreason: The Michael van Gerwen article is likely trending on Wikipedia due to his recent victory at a major darts tournament, reinforcing his status as one of the top players in the sport.
# Analyzing Michael_van_Gerwen
# trendingreason: The article on Pan Am Flight 103 might be trending on Wikipedia as it marks the 37th anniversary of the Lockerbie bombing, a significant and tragic event in aviation history and international terrorism.
# Analyzing Pan_Am_Flight_103
# trendingreason: The "Deaths in 2025" article is trending on Wikipedia as it documents notable losses from the very start of the year, making it a timely reference for those seeking updates on significant figures who have recently passed away.
# Analyzing Deaths_in_2025
# trendingreason: The article on "Mufasa: The Lion King" is likely trending on Wikipedia due to the film's recent release on December 20, 2024, its star-studded cast, and significant box office performance amidst ongoing discussions about its critical reception.
# Analyzing Mufasa:_The_Lion_King
# trendingreason: The Norovirus article is likely trending on Wikipedia due to heightened public interest in gastroenteritis outbreaks typically associated with winter months, when the virus is most prevalent and widely recognized as a significant health concern.
# Analyzing Norovirus
# trendingreason: The Wicked (2024 film) article is likely trending on Wikipedia due to its successful debut, having grossed $681.2 million and garnered significant attention as a highly anticipated adaptation of the beloved musical, further heightened by performances from star-studded cast members like Cynthia Erivo and Ariana Grande.
# Analyzing Wicked_(2024_film)
# trendingreason: The article for *Marco* (2024 film) might be trending on Wikipedia as of January 4, 2025, due to its remarkable box office success, having become the highest-grossing A-rated Malayalam film of all time shortly after its release on December 20, 2024.
# Analyzing Marco_(2024_film)
# trendingreason: The article on the highest-grossing Indian films is likely trending on Wikipedia due to recent major box office successes in Indian cinema, particularly from regional films, that have reshaped the rankings and sparked public interest in the evolving landscape of the industry.

# %% [markdown]
# Kept running into rate limit errors... But the results I was getting are very positive and close to what I was looking for.
#
# On the downside.. running this for two days hit the Tokens Per Minute limits and cost almost $7....
#
# This is enough for this

# %% [markdown]
# ### Save vital information to new file

# %%
file_path = f'{file_directory}/{base_file_name}-trending-reasons.json'

# Save to JSON file (overwrite if it already exists)
with open(file_path, 'w', encoding='utf-8') as file:
    json.dump(article_list, file, indent=4, ensure_ascii=False)

print(f'articles_with_reasons saved to {file_path}')
# Out:
# articles_with_reasons saved to data/2025-01-04-trending-reasons.json

# %% [markdown]
# #### Build HTML Page to display the top 10 list complete with thumbnails and the reason generated by ChatGPT

# %%
# Start building the HTML
html_title = f"<h1>Wikipedia's most viewed articles on {date_to_query.strftime("%B %d, %Y")}</h1>"
html_list = "<ol>\n"

# Iterate through the data
for item in article_list:
    title = item['title']
    link = item['link']
    thumbnail = item['thumbnail']
    trendingreason = item['trendingreason']
    views = item['views']
    extract = item['extract']

    # Handle null thumbnail
    if thumbnail:
        thumbnail_html = f'<img src="{thumbnail}" alt="Thumbnail for {title}"/><br>'
    else:
        thumbnail_html = '<p><em>No thumbnail available</em></p>'
    
    # Create a list item for each entry
    html_list += f"""
    <li>
        <h2>
          <a href="{link}" target="_blank">{title}</a><br>
        </h2>
        {thumbnail_html}
        <strong>Views:</strong> {views}<br><br>
        <strong>Reason for Trending:</strong> {trendingreason}
    </li>\n
    """

# Close the HTML list
html_list += "</ol>"

html_page = html_title + html_list
# Save to html file (overwrite if it already exists)
file_path = f'{file_directory}/{base_file_name}.html'

with open(file_path, 'w', encoding='utf-8') as file:
    file.write(html_page)

# Display the HTML in the notebook
from IPython.display import display, HTML
display(HTML(html_page))
# Out:
# <h1>Wikipedia's most viewed articles on January 04, 2025</h1><ol>
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Squid_Game_season_2" target="_blank">Squid_Game_season_2</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/en/3/38/Squid_Game_season_2_poster.png" alt="Thumbnail for Squid_Game_season_2"/><br>
#         <strong>Views:</strong> 336056<br><br>
#         <strong>Reason for Trending:</strong> The article on Squid Game Season 2 is likely trending on Wikipedia due to its recent release on December 26, 2024, generating significant viewer interest and discussion about its continuation shortly before the anticipated third and final season.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Luke_Littler" target="_blank">Luke_Littler</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/0/06/Luke_Littler.png/320px-Luke_Littler.png" alt="Thumbnail for Luke_Littler"/><br>
#         <strong>Views:</strong> 316702<br><br>
#         <strong>Reason for Trending:</strong> Luke Littler is trending on Wikipedia due to his historic achievement as the youngest PDC World Darts Champion, winning the title at just 17 years and 347 days old.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Marcus_Freeman" target="_blank">Marcus_Freeman</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/0/01/Marcus_Freeman%2C_University_of_Notre_Dame_Football_Team_Head_Coach_at_the_Pentagon_on_May_9%2C_2024_%28cropped%29.jpg/320px-Marcus_Freeman%2C_University_of_Notre_Dame_Football_Team_Head_Coach_at_the_Pentagon_on_May_9%2C_2024_%28cropped%29.jpg" alt="Thumbnail for Marcus_Freeman"/><br>
#         <strong>Views:</strong> 303443<br><br>
#         <strong>Reason for Trending:</strong> The article about Marcus Freeman might be trending on Wikipedia on January 4, 2025, due to his recognition as the Bobby Dodd Coach of the Year in 2024, signaling his prominent impact and achievements as the head coach of the Notre Dame Fighting Irish football team.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Nosferatu_(2024_film)" target="_blank">Nosferatu_(2024_film)</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/en/4/48/Nosferatu_IMAX_poster_2024.jpg" alt="Thumbnail for Nosferatu_(2024_film)"/><br>
#         <strong>Views:</strong> 223589<br><br>
#         <strong>Reason for Trending:</strong> The article about the Nosferatu (2024 film) is trending on Wikipedia due to its recent theatrical release, critical acclaim, and impressive box office success, grossing over $100 million shortly after its premiere.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Squid_Game" target="_blank">Squid_Game</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/e4/Squid_Game_2021_vector_logo.svg/320px-Squid_Game_2021_vector_logo.svg.png" alt="Thumbnail for Squid_Game"/><br>
#         <strong>Views:</strong> 186445<br><br>
#         <strong>Reason for Trending:</strong> The article about "Squid Game" is trending on Wikipedia likely due to the recent release of its highly anticipated second season on December 26, 2024, which has reignited global interest in the series.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Human_metapneumovirus" target="_blank">Human_metapneumovirus</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/e1/Pathogens-04-00682-g001.png/320px-Pathogens-04-00682-g001.png" alt="Thumbnail for Human_metapneumovirus"/><br>
#         <strong>Views:</strong> 160403<br><br>
#         <strong>Reason for Trending:</strong> The Human Metapneumovirus article is trending on Wikipedia due to a notable outbreak reported in China at the end of 2024, prompting increased public interest and concern over its impact on respiratory illness, particularly in vulnerable populations.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Pushpa_2%3A_The_Rule" target="_blank">Pushpa_2:_The_Rule</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/en/1/11/Pushpa_2-_The_Rule.jpg" alt="Thumbnail for Pushpa_2:_The_Rule"/><br>
#         <strong>Views:</strong> 151040<br><br>
#         <strong>Reason for Trending:</strong> The article on "Pushpa 2: The Rule" is likely trending on Wikipedia on January 4, 2025, due to its recent theatrical release on December 5, 2024, and its impressive box office performance, grossing over ₹1,700 crore globally, capturing significant public and media interest.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Wayne_Osmond" target="_blank">Wayne_Osmond</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/7/7a/Wayne_Osmond_%28cropped%29.JPG/320px-Wayne_Osmond_%28cropped%29.JPG" alt="Thumbnail for Wayne_Osmond"/><br>
#         <strong>Views:</strong> 149195<br><br>
#         <strong>Reason for Trending:</strong> The Wayne Osmond article is trending on Wikipedia following his recent death on January 1, 2025, which has sparked widespread public interest and tributes to his contributions as a musician with The Osmonds.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/Avicii" target="_blank">Avicii</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Avicii_2014_003cr.jpg/320px-Avicii_2014_003cr.jpg" alt="Thumbnail for Avicii"/><br>
#         <strong>Views:</strong> 142325<br><br>
#         <strong>Reason for Trending:</strong> The Avicii article might be trending on Wikipedia on January 4, 2025, due to renewed interest following a significant anniversary of his passing or the release of new posthumous material that has reignited public and media discussions about his impact on music and EDM culture.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/PDC_World_Darts_Championship" target="_blank">PDC_World_Darts_Championship</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f7/PDC_World_Darts_Championship_2016.jpg/320px-PDC_World_Darts_Championship_2016.jpg" alt="Thumbnail for PDC_World_Darts_Championship"/><br>
#         <strong>Views:</strong> 141136<br><br>
#         <strong>Reason for Trending:</strong> The PDC World Darts Championship article is likely trending on Wikipedia following the conclusion of the 2025 tournament, where Luke Littler emerged as the champion, drawing significant attention and interest in the sport.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/2025_PDC_World_Darts_Championship" target="_blank">2025_PDC_World_Darts_Championship</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/0/06/Luke_Littler.png/320px-Luke_Littler.png" alt="Thumbnail for 2025_PDC_World_Darts_Championship"/><br>
#         <strong>Views:</strong> 133581<br><br>
#         <strong>Reason for Trending:</strong> The 2025 PDC World Darts Championship article is trending on Wikipedia because it features the historic victory of 17-year-old Luke Littler, who became the youngest world champion in darts history, capturing significant attention during and after the tournament's conclusion.
#     </li>
#
#
#     <li>
#         <h2>
#           <a href="https://en.wikipedia.org/wiki/2025_New_Orleans_truck_attack" target="_blank">2025_New_Orleans_truck_attack</a><br>
#         </h2>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Crowd_panicking_after_the_2025_New_Orleans_truck_attack.webm/320px--Crowd_panicking_after_the_2025_New_Orleans_truck_attack.webm.jpg" alt="Thumbnail for 2025_New_Orleans_truck_attack"/><br>
#         <strong>View

# %% [markdown]
# # What I've playing around with Phoenix
#
# The traces visible in Phoenix make it so much easier to look at the entire prompt and result to get a better insight into the results than you can get through print statements in the notebook. I see it as a magnifying glass and complete historic record.
#
# - For Jimmy Carter's article, it needed 500 characters to get the general detail of his recent death in December 2024 and 2000 characters to get the context the full date of death
# - droping max_tokens from 2048 to 512 didn't have a discernable difference
# - Changing the prompt from "In 1-2 sentences, explain why the..." to "In 1 concise and confident sentence, explain why..." gave results I prefer
